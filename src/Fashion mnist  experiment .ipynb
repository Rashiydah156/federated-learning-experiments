# %%
#install tensorflow tensorflow_federated
# !pip install tensorflow tensorflow_federated
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.14.1)
# Requirement already satisfied: tensorflow_federated in /usr/local/lib/python3.11/dist-packages (0.84.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes==0.2.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.25.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (22.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.25.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.70.0)
# Requirement already satisfied: tensorboard<2.15,>=2.14 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.14.1)
# Requirement already satisfied: tensorflow-estimator<2.15,>=2.14.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: keras<2.15,>=2.14.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: attrs~=23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow_federated) (23.1.0)
# Requirement already satisfied: cachetools~=5.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow_federated) (5.5.1)
# Requirement already satisfied: dm-tree==0.1.8 in /usr/local/lib/python3.11/dist-packages (from tensorflow_federated) (0.1.8)
# Requirement already satisfied: dp-accounting==0.4.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow_federated) (0.4.3)
# Requirement already satisfied: google-vizier==0.1.11 in /usr/local/lib/python3.11/dist-packages (from tensorflow_federated) (0.1.11)
# Requirement already satisfied: jaxlib==0.4.14 in /usr/local/lib/python3.11/dist-packages (from tensorflow_federated) (0.4.14)
# Requirement already satisfied: jax==0.4.14 in /usr/local/lib/python3.11/dist-packages (from tensorflow_federated) (0.4.14)
# Requirement already satisfied: portpicker~=1.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow_federated) (1.6.0)
# Requirement already satisfied: scipy~=1.9.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow_federated) (1.9.3)
# Requirement already satisfied: tensorflow-model-optimization==0.7.5 in /usr/local/lib/python3.11/dist-packages (from tensorflow_federated) (0.7.5)
# Requirement already satisfied: tensorflow-privacy==0.9.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow_federated) (0.9.0)
# Requirement already satisfied: tqdm~=4.64 in /usr/local/lib/python3.11/dist-packages (from tensorflow_federated) (4.67.1)
# Requirement already satisfied: googleapis-common-protos==1.61.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow_federated) (1.61.0)
# Requirement already satisfied: mpmath~=1.2 in /usr/local/lib/python3.11/dist-packages (from dp-accounting==0.4.3->tensorflow_federated) (1.3.0)
# Requirement already satisfied: grpcio-tools>=1.35.0 in /usr/local/lib/python3.11/dist-packages (from google-vizier==0.1.11->tensorflow_federated) (1.62.3)
# Requirement already satisfied: sqlalchemy<=1.4.20,>=1.4 in /usr/local/lib/python3.11/dist-packages (from google-vizier==0.1.11->tensorflow_federated) (1.4.20)
# Requirement already satisfied: scikit-learn==1.*,>=1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow-privacy==0.9.0->tensorflow_federated) (1.6.1)
# Requirement already satisfied: tensorflow-probability~=0.22.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow-privacy==0.9.0->tensorflow_federated) (0.22.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.*,>=1.0->tensorflow-privacy==0.9.0->tensorflow_federated) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.*,>=1.0->tensorflow-privacy==0.9.0->tensorflow_federated) (3.5.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from portpicker~=1.6->tensorflow_federated) (5.9.5)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (3.1.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (2025.1.31)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy<=1.4.20,>=1.4->google-vizier==0.1.11->tensorflow_federated) (3.1.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from tensorflow-probability~=0.22.0->tensorflow-privacy==0.9.0->tensorflow_federated) (4.4.2)
# Requirement already satisfied: cloudpickle>=1.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow-probability~=0.22.0->tensorflow-privacy==0.9.0->tensorflow_federated) (3.1.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow) (3.2.2)

# %%
#importing approriate dependencies
import os
import pickle
import numpy as np
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
import tensorflow_federated as tff
from tensorflow_federated.python.learning.models import from_keras_model
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
# Out:
# ERROR:jax._src.xla_bridge:Jax plugin configuration error: Exception when calling jax_plugins.xla_cuda12.initialize()
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/jax/_src/xla_bridge.py", line 438, in discover_pjrt_plugins
#     plugin_module.initialize()
#   File "/usr/local/lib/python3.11/dist-packages/jax_plugins/xla_cuda12/__init__.py", line 85, in initialize
#     options = xla_client.generate_pjrt_gpu_plugin_options()
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'jaxlib.xla_client' has no attribute 'generate_pjrt_gpu_plugin_options'

# %%
print("TensorFlow Federated Version:", tff.__version__)
# Out:
# TensorFlow Federated Version: 0.84.0

# %% [markdown]
# **EXPERIMENT ONE**

# %%
import tensorflow as tf
import numpy as np
import time
import matplotlib.pyplot as plt

# Loading and preprocessing the FashionMNIST dataset
def load_and_preprocess_data():
    (x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

    # Preprocessing: normalize to [0,1] and reshaping to (28, 28, 1)
    x_train = x_train.astype('float32') / 255.0
    x_test = x_test.astype('float32') / 255.0
    x_train = np.expand_dims(x_train, axis=-1)
    x_test = np.expand_dims(x_test, axis=-1)

    # One-hot encoding labels
    y_train = tf.keras.utils.to_categorical(y_train, num_classes=10)
    y_test = tf.keras.utils.to_categorical(y_test, num_classes=10)

    return (x_train, y_train), (x_test, y_test)

# Define the global CNN model
def create_cnn_model():
    model = tf.keras.Sequential([
        tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(10, activation='softmax')
    ])
    return model

# Create federated data by splitting the dataset among clients
def create_federated_data(x, y, num_clients=10):
    client_data = []
    data_per_client = len(x) // num_clients
    for i in range(num_clients):
        client_x = x[i * data_per_client:(i + 1) * data_per_client]
        client_y = y[i * data_per_client:(i + 1) * data_per_client]
        client_data.append((client_x, client_y))
    return client_data

# Measure communication overhead
def measure_communication_overhead(weights):
    return sum([np.prod(w.shape) for w in weights]) * 4 / (1024 * 1024)  # in MB

# Federated learning parameters
num_clients = 10
num_rounds = 30
local_epochs = 3
accuracy_threshold = 0.70  # Define an accuracy threshold for convergence speed

# Load and preprocess data
(x_train, y_train), (x_test, y_test) = load_and_preprocess_data()

# Create federated data for each client
federated_train_data = create_federated_data(x_train, y_train, num_clients)

# Create global model
global_model = create_cnn_model()
global_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Initialize variables to measure communication overhead and convergence speed
total_communication_overhead = 0
convergence_round = None
start_time = time.time()

# Lists to store metrics for visualization
communication_overheads = []
accuracies = []
round_times = []

# Federated learning loop
for round_num in range(num_rounds):
    print(f"Round {round_num + 1}/{num_rounds}")

    local_weights = []
    round_start_time = time.time()

    # Train on each client
    for client_id in range(num_clients):
        print(f"Training on client {client_id + 1}")

        # Create local model and set global weights
        local_model = create_cnn_model()
        local_model.set_weights(global_model.get_weights())
        local_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

        # Get client data
        X, y = federated_train_data[client_id]

        # Train local model
        local_model.fit(X, y, epochs=local_epochs, batch_size=32, verbose=0)

        # Collect local model weights
        local_weights.append(local_model.get_weights())

    # Federated averaging: Aggregate local weights
    averaged_weights = [np.mean([local_weights[j][i] for j in range(num_clients)], axis=0)
                        for i in range(len(local_weights[0]))]

    # Measure communication overhead
    round_communication_overhead = measure_communication_overhead(averaged_weights)
    total_communication_overhead += round_communication_overhead
    communication_overheads.append(round_communication_overhead)
    print(f"Communication overhead for round {round_num + 1}: {round_communication_overhead:.4f} MB")

    # Update global model weights
    global_model.set_weights(averaged_weights)

    # Evaluate the global model
    loss, accuracy = global_model.evaluate(x_test, y_test, verbose=0)
    accuracies.append(accuracy)
    print(f"Global model accuracy after round {round_num + 1}: {accuracy:.4f}")

    # Check for convergence
    if convergence_round is None and accuracy >= accuracy_threshold:
        convergence_round = round_num + 1
        convergence_time = time.time() - start_time
        print(f"Convergence achieved at round {convergence_round} with accuracy {accuracy:.4f}")
        print(f"Convergence time: {convergence_time:.2f} seconds")

    # Record round time
    round_time = time.time() - round_start_time
    round_times.append(round_time)

# Evaluate the final global model
final_loss, final_accuracy = global_model.evaluate(x_test, y_test, verbose=0)
print(f"Final global model accuracy: {final_accuracy:.4f}")

# Print total communication overhead
print(f"Total communication overhead: {total_communication_overhead:.4f} MB")

# Print convergence information if not already printed
if convergence_round is None:
    convergence_time = time.time() - start_time
    print(f"Convergence not achieved within {num_rounds} rounds.")
else:
    print(f"Convergence achieved at round {convergence_round} with accuracy {final_accuracy:.4f}")
    print(f"Convergence time: {convergence_time:.2f} seconds")

# Visualization
rounds = list(range(1, num_rounds + 1))

plt.figure(figsize=(12, 6))

# Plot communication overhead
plt.subplot(1, 3, 1)
plt.plot(rounds, communication_overheads, marker='o')
plt.title('Communication Overhead per Round')
plt.xlabel('Round')
plt.ylabel('Communication Overhead (MB)')

# Plot accuracy
plt.subplot(1, 3, 2)
plt.plot(rounds, accuracies, marker='o')
plt.title('Global Model Accuracy per Round')
plt.xlabel('Round')
plt.ylabel('Accuracy')

# Plot round times
plt.subplot(1, 3, 3)
plt.plot(rounds, round_times, marker='o')
plt.title('Round Time')
plt.xlabel('Round')
plt.ylabel('Time (seconds)')

plt.tight_layout()
plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Round 1/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 1: 0.3560 MB
# Global model accuracy after round 1: 0.7897
# Convergence achieved at round 1 with accuracy 0.7897
# Convergence time: 92.93 seconds
# Round 2/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 2: 0.3560 MB
# Global model accuracy after round 2: 0.8586
# Round 3/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 3: 0.3560 MB
# Global model accuracy after round 3: 0.8768
# Round 4/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 4: 0.3560 MB
# Global model accuracy after round 4: 0.8869
# Round 5/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 5: 0.3560 MB
# Global model accuracy after round 5: 0.8940
# Round 6/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 6: 0.3560 MB
# Global model accuracy after round 6: 0.8971
# Round 7/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 7: 0.3560 MB
# Global model accuracy after round 7: 0.8999
# Round 8/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 8: 0.3560 MB
# Global model accuracy after round 8: 0.9026
# Round 9/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 9: 0.3560 MB
# Global model accuracy after round 9: 0.9048
# Round 10/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 10: 0.3560 MB
# Global model accuracy after round 10: 0.9067
# Round 11/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 11: 0.3560 MB
# Global model accuracy after round 11: 0.9077
# Round 12/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 12: 0.3560 MB
# Global model accuracy after round 12: 0.9086
# Round 13/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 13: 0.3560 MB
# Global model accuracy after round 13: 0.9081
# Round 14/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 14: 0.3560 MB
# Global model accuracy after round 14: 0.9083
# Round 15/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 15: 0.3560 MB
# Global model accuracy after round 15: 0.9091
# Round 16/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 16: 0.3560 MB
# Global model accuracy after round 16: 0.9089
# Round 17/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 17: 0.3560 MB
# Global model accuracy after round 17: 0.9089
# Round 18/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 18: 0.3560 MB
# Global model accuracy after round 18: 0.9099
# Round 19/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 19: 0.3560 MB
# Global model accuracy after round 19: 0.9094
# Round 20/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 20: 0.3560 MB
# Global model accuracy after round 20: 0.9107
# Round 21/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 21: 0.3560 MB
# Global model accuracy after round 21: 0.9097
# Round 22/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 22: 0.3560 MB
# Global model accuracy after round 22: 0.9109
# Round 23/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 23: 0.3560 MB
# Global model accuracy after round 23: 0.9114
# Round 24/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 24: 0.3560 MB
# Global model accuracy after round 24: 0.9103
# Round 25/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 25: 0.3560 MB
# Global model accuracy after round 25: 0.9110
# Round 26/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 26: 0.3560 MB
# Global model accuracy after round 26: 0.9098
# Round 27/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 27: 0.3560 MB
# Global model accuracy after round 27: 0.9115
# Round 28/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 28: 0.3560 MB
# Global model accuracy after round 28: 0.9115
# Round 29/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 29: 0.3560 MB
# Global model accuracy after round 29: 0.9100
# Round 30/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 30: 0.3560 MB
# Global model accuracy after round 30: 0.9125
# Final global model accuracy: 0.9125
# Total communication overhead: 10.6799 MB
# Convergence achieved at round 1 with accuracy 0.9125
# Convergence time: 92.93 seconds

# %% [markdown]
# **EXPERIMENT TWO**

# %%
import tensorflow as tf
import numpy as np
import time
import matplotlib.pyplot as plt

# Load and preprocess the FashionMNIST dataset
def load_and_preprocess_data():
    (x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

    # Preprocessing: normalize to [0,1] and reshape to (28, 28, 1)
    x_train = x_train.astype('float32') / 255.0
    x_test = x_test.astype('float32') / 255.0
    x_train = np.expand_dims(x_train, axis=-1)
    x_test = np.expand_dims(x_test, axis=-1)

    # One-hot encode labels
    y_train = tf.keras.utils.to_categorical(y_train, num_classes=10)
    y_test = tf.keras.utils.to_categorical(y_test, num_classes=10)

    return (x_train, y_train), (x_test, y_test)

# Define the global CNN model
def create_cnn_model():
    model = tf.keras.Sequential([
        tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(10, activation='softmax')
    ])
    return model

# Create federated data by splitting the dataset among clients
def create_federated_data(x, y, num_clients=10):
    client_data = []
    data_per_client = len(x) // num_clients
    for i in range(num_clients):
        client_x = x[i * data_per_client:(i + 1) * data_per_client]
        client_y = y[i * data_per_client:(i + 1) * data_per_client]
        client_data.append((client_x, client_y))
    return client_data

# Measure communication overhead
def measure_communication_overhead(weights):
    return sum([np.prod(w.shape) for w in weights]) * 4 / (1024 * 1024)  # in MB

# Federated learning parameters
num_clients = 20
num_rounds = 30
local_epochs = 3
accuracy_threshold = 0.70  # Define an accuracy threshold for convergence speed

# Load and preprocess data
(x_train, y_train), (x_test, y_test) = load_and_preprocess_data()

# Create federated data for each client
federated_train_data = create_federated_data(x_train, y_train, num_clients)

# Create global model
global_model = create_cnn_model()
global_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Initialize variables to measure communication overhead and convergence speed
total_communication_overhead = 0
convergence_round = None
start_time = time.time()

# Lists to store metrics for visualization
communication_overheads = []
accuracies = []
round_times = []

# Federated learning loop
for round_num in range(num_rounds):
    print(f"Round {round_num + 1}/{num_rounds}")

    local_weights = []
    round_start_time = time.time()

    # Train on each client
    for client_id in range(num_clients):
        print(f"Training on client {client_id + 1}")

        # Create local model and set global weights
        local_model = create_cnn_model()
        local_model.set_weights(global_model.get_weights())
        local_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

        # Get client data
        X, y = federated_train_data[client_id]

        # Train local model
        local_model.fit(X, y, epochs=local_epochs, batch_size=32, verbose=0)

        # Collect local model weights
        local_weights.append(local_model.get_weights())

    # Federated averaging: Aggregate local weights
    averaged_weights = [np.mean([local_weights[j][i] for j in range(num_clients)], axis=0)
                        for i in range(len(local_weights[0]))]

    # Measure communication overhead
    round_communication_overhead = measure_communication_overhead(averaged_weights)
    total_communication_overhead += round_communication_overhead
    communication_overheads.append(round_communication_overhead)
    print(f"Communication overhead for round {round_num + 1}: {round_communication_overhead:.4f} MB")

    # Update global model weights
    global_model.set_weights(averaged_weights)

    # Evaluate the global model
    loss, accuracy = global_model.evaluate(x_test, y_test, verbose=0)
    accuracies.append(accuracy)
    print(f"Global model accuracy after round {round_num + 1}: {accuracy:.4f}")

    # Check for convergence
    if convergence_round is None and accuracy >= accuracy_threshold:
        convergence_round = round_num + 1
        convergence_time = time.time() - start_time
        print(f"Convergence achieved at round {convergence_round} with accuracy {accuracy:.4f}")
        print(f"Convergence time: {convergence_time:.2f} seconds")

    # Record round time
    round_time = time.time() - round_start_time
    round_times.append(round_time)

# Evaluate the final global model
final_loss, final_accuracy = global_model.evaluate(x_test, y_test, verbose=0)
print(f"Final global model accuracy: {final_accuracy:.4f}")

# Print total communication overhead
print(f"Total communication overhead: {total_communication_overhead:.4f} MB")

# Print convergence information if not already printed
if convergence_round is None:
    convergence_time = time.time() - start_time
    print(f"Convergence not achieved within {num_rounds} rounds.")
else:
    print(f"Convergence achieved at round {convergence_round} with accuracy {final_accuracy:.4f}")
    print(f"Convergence time: {convergence_time:.2f} seconds")

# Visualization
rounds = list(range(1, num_rounds + 1))

plt.figure(figsize=(12, 6))

# Plot communication overhead
plt.subplot(1, 3, 1)
plt.plot(rounds, communication_overheads, marker='o')
plt.title('Communication Overhead per Round')
plt.xlabel('Round')
plt.ylabel('Communication Overhead (MB)')

# Plot accuracy
plt.subplot(1, 3, 2)
plt.plot(rounds, accuracies, marker='o')
plt.title('Global Model Accuracy per Round')
plt.xlabel('Round')
plt.ylabel('Accuracy')

# Plot round times
plt.subplot(1, 3, 3)
plt.plot(rounds, round_times, marker='o')
plt.title('Round Time')
plt.xlabel('Round')
plt.ylabel('Time (seconds)')

plt.tight_layout()
plt.show()
# Out:
# Round 1/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 1: 0.3560 MB
# Global model accuracy after round 1: 0.7710
# Convergence achieved at round 1 with accuracy 0.7710
# Convergence time: 109.72 seconds
# Round 2/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 2: 0.3560 MB
# Global model accuracy after round 2: 0.8259
# Round 3/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 3: 0.3560 MB
# Global model accuracy after round 3: 0.8534
# Round 4/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 4: 0.3560 MB
# Global model accuracy after round 4: 0.8688
# Round 5/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 5: 0.3560 MB
# Global model accuracy after round 5: 0.8748
# Round 6/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 6: 0.3560 MB
# Global model accuracy after round 6: 0.8817
# Round 7/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 7: 0.3560 MB
# Global model accuracy after round 7: 0.8846
# Round 8/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 8: 0.3560 MB
# Global model accuracy after round 8: 0.8876
# Round 9/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 9: 0.3560 MB
# Global model accuracy after round 9: 0.8914
# Round 10/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 10: 0.3560 MB
# Global model accuracy after round 10: 0.8948
# Round 11/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 11: 0.3560 MB
# Global model accuracy after round 11: 0.8974
# Round 12/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 12: 0.3560 MB
# Global model accuracy after round 12: 0.8971
# Round 13/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 13: 0.3560 MB
# Global model accuracy after round 13: 0.9004
# Round 14/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 14: 0.3560 MB
# Global model accuracy after round 14: 0.9015
# Round 15/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 15: 0.3560 MB
# Global model accuracy after round 15: 0.9008
# Round 16/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 16: 0.3560 MB
# Global model accuracy after round 16: 0.9034
# Round 17/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 17: 0.3560 MB
# Global model accuracy after round 17: 0.9046
# Round 18/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 18: 0.3560 MB
# Global model accuracy after round 18: 0.9041
# Round 19/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 19: 0.3560 MB
# Global model accuracy after round 19: 0.9046
# Round 20/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 20: 0.3560 MB
# Global model accuracy after round 20: 0.9057
# Round 21/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 21: 0.3560 MB
# Global model accuracy after round 21: 0.9070
# Round 22/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 22: 0.3560 MB
# Global model accuracy after round 22: 0.9072
# Round 23/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 23: 0.3560 MB
# Global model accuracy after round 23: 0.9089
# Round 24/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 24: 0.3560 MB
# Global model accuracy after round 24: 0.9077
# Round 25/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 25: 0.3560 MB
# Global model accuracy after round 25: 0.9088
# Round 26/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 26: 0.3560 MB
# Global model accuracy after round 26: 0.9099
# Round 27/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 27: 0.3560 MB
# Global model accuracy after round 27: 0.9098
# Round 28/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 28: 0.3560 MB
# Global model accuracy after round 28: 0.9107
# Round 29/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 29: 0.3560 MB
# Global model accuracy after round 29: 0.9098
# Round 30/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 30: 0.3560 MB
# Global model accuracy after round 30: 0.9106
# Final global model accuracy: 0.9106
# Total communication overhead: 10.6799 MB
# Convergence achieved at round 1 with accuracy 0.9106
# Convergence time: 109.72 seconds

# %% [markdown]
# **EXPERIMENT THREE**

# %%
import tensorflow as tf
import numpy as np
import time
import matplotlib.pyplot as plt

# Load and preprocess the FashionMNIST dataset
def load_and_preprocess_data():
    (x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

    # Preprocessing: normalize to [0,1] and reshape to (28, 28, 1)
    x_train = x_train.astype('float32') / 255.0
    x_test = x_test.astype('float32') / 255.0
    x_train = np.expand_dims(x_train, axis=-1)
    x_test = np.expand_dims(x_test, axis=-1)

    # One-hot encode labels
    y_train = tf.keras.utils.to_categorical(y_train, num_classes=10)
    y_test = tf.keras.utils.to_categorical(y_test, num_classes=10)

    return (x_train, y_train), (x_test, y_test)

# Define the global CNN model
def create_cnn_model():
    model = tf.keras.Sequential([
        tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(10, activation='softmax')
    ])
    return model

# Create federated data by splitting the dataset among clients
def create_federated_data(x, y, num_clients=10):
    client_data = []
    data_per_client = len(x) // num_clients
    for i in range(num_clients):
        client_x = x[i * data_per_client:(i + 1) * data_per_client]
        client_y = y[i * data_per_client:(i + 1) * data_per_client]
        client_data.append((client_x, client_y))
    return client_data

# Measure communication overhead
def measure_communication_overhead(weights):
    return sum([np.prod(w.shape) for w in weights]) * 4 / (1024 * 1024)  # in MB

# Federated learning parameters
num_clients =
# Round 22/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Communication overhead for round 22: 0.3560 MB
# Global model accuracy after round 22: 0.8769
# Round 23/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Communication overhead for round 23: 0.3560 MB
# Global model accuracy after round 23: 0.8779
# Round 24/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Communication overhead for round 24: 0.3560 MB
# Global model accuracy after round 24: 0.8788
# Round 25/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Communication overhead for round 25: 0.3560 MB
# Global model accuracy after round 25: 0.8799
# Round 26/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Communication overhead for round 26: 0.3560 MB
# Global model accuracy after round 26: 0.8810
# Round 27/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Communication overhead for round 27: 0.3560 MB
# Global model accuracy after round 27: 0.8825
# Round 28/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Communication overhead for round 28: 0.3560 MB
# Global model accuracy after round 28: 0.8840
# Round 29/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Communication overhead for round 29: 0.3560 MB
# Global model accuracy after round 29: 0.8861
# Round 30/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Communication overhead for round 30: 0.3560 MB
# Global model accuracy after round 30: 0.8870
# Final global model accuracy: 0.8870
# Total communication overhead: 10.6799 MB
# Convergence achieved at round 2 with accuracy 0.8870
# Convergence time: 382.01 seconds

# %% [markdown]
# **EXPERIMENT TEN**

# %%
import tensorflow as tf
import numpy as np
import time
import matplotlib.pyplot as plt

# Load and preprocess the FashionMNIST dataset
def load_and_preprocess_data():
    (x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

    # Preprocessing: normalize to [0,1] and reshape to (28, 28, 1)
    x_train = x_train.astype('float32') / 255.0
    x_test = x_test.astype('float32') / 255.0
    x_train = np.expand_dims(x_train, axis=-1)
    x_test = np.expand_dims(x_test, axis=-1)

    # One-hot encode labels
    y_train = tf.keras.utils.to_categorical(y_train, num_classes=10)
    y_test = tf.keras.utils.to_categorical(y_test, num_classes=10)

    return (x_train, y_train), (x_test, y_test)

# Define the global CNN model
def create_cnn_model():
    model = tf.keras.Sequential([
        tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(10, activation='softmax')
    ])
    return model

# Create federated data by splitting the dataset among clients
def create_federated_data(x, y, num_clients=10):
    client_data = []
    data_per_client = len(x) // num_clients
    for i in range(num_clients):
        client_x = x[i * data_per_client:(i + 1) * data_per_client]
        client_y = y[i * data_per_client:(i + 1) * data_per_client]
        client_data.append((client_x, client_y))
    return client_data

# Measure communication overhead
def measure_communication_overhead(weights):
    return sum([np.prod(w.shape) for w in weights]) * 4 / (1024 * 1024)  # in MB

# Federated learning parameters
num_clients = 100
num_rounds = 30
local_epochs = 3
accuracy_threshold = 0.70  # Define an accuracy threshold for convergence speed

# Load and preprocess data
(x_train, y_train), (x_test, y_test) = load_and_preprocess_data()

# Create federated data for each client
federated_train_data = create_federated_data(x_train, y_train, num_clients)

# Create global model
global_model = create_cnn_model()
global_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Initialize variables to measure communication overhead and convergence speed
total_communication_overhead = 0
convergence_round = None
start_time = time.time()

# Lists to store metrics for visualization
communication_overheads = []
accuracies = []
round_times = []

# Federated learning loop
for round_num in range(num_rounds):
    print(f"Round {round_num + 1}/{num_rounds}")

    local_weights = []
    round_start_time = time.time()

    # Train on each client
    for client_id in range(num_clients):
        print(f"Training on client {client_id + 1}")

        # Create local model and set global weights
        local_model = create_cnn_model()
        local_model.set_weights(global_model.get_weights())
        local_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

        # Get client data
        X, y = federated_train_data[client_id]

        # Train local model
        local_model.fit(X, y, epochs=local_epochs, batch_size=32, verbose=0)

        # Collect local model weights
        local_weights.append(local_model.get_weights())

    # Federated averaging: Aggregate local weights
    averaged_weights = [np.mean([local_weights[j][i] for j in range(num_clients)], axis=0)
                        for i in range(len(local_weights[0]))]

    # Measure communication overhead
    round_communication_overhead = measure_communication_overhead(averaged_weights)
    total_communication_overhead += round_communication_overhead
    communication_overheads.append(round_communication_overhead)
    print(f"Communication overhead for round {round_num + 1}: {round_communication_overhead:.4f} MB")

    # Update global model weights
    global_model.set_weights(averaged_weights)

    # Evaluate the global model
    loss, accuracy = global_model.evaluate(x_test, y_test, verbose=0)
    accuracies.append(accuracy)
    print(f"Global model accuracy after round {round_num + 1}: {accuracy:.4f}")

    # Check for convergence
    if convergence_round is None and accuracy >= accuracy_threshold:
        convergence_round = round_num + 1
        convergence_time = time.time() - start_time
        print(f"Convergence achieved at round {convergence_round} with accuracy {accuracy:.4f}")
        print(f"Convergence time: {convergence_time:.2f} seconds")

    # Record round time
    round_time = time.time() - round_start_time
    round_times.append(round_time)

# Evaluate the final global model
final_loss, final_accuracy = global_model.evaluate(x_test, y_test, verbose=0)
print(f"Final global model accuracy: {final_accuracy:.4f}")

# Print total communication overhead
print(f"Total communication overhead: {total_communication_overhead:.4f} MB")

# Print convergence information if not already printed
if convergence_round is None:
    convergence_time = time.time() - start_time
    print(f"Convergence not achieved within {num_rounds} rounds.")
else:
    print(f"Convergence achieved at round {convergence_round} with accuracy {final_accuracy:.4f}")
    print(f"Convergence time: {convergence_time:.2f} seconds")

# Visualization
rounds = list(range(1, num_rounds + 1))

plt.figure(figsize=(12, 6))

# Plot communication overhead
plt.subplot(1, 3, 1)
plt.plot(rounds, communication_overheads, marker='o')
plt.title('Communication Overhead per Round')
plt.xlabel('Round')
plt.ylabel('Communication Overhead (MB)')

# Plot accuracy
plt.subplot(1, 3, 2)
plt.plot(rounds, accuracies, marker='o')
plt.title('Global Model Accuracy per Round')
plt.xlabel('Round')
plt.ylabel('Accuracy')

# Plot round times
plt.subplot(1, 3, 3)
plt.plot(rounds, round_times, marker='o')
plt.title('Round Time')
plt.xlabel('Round')
plt.ylabel('Time (seconds)')

plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Round 1/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 1: 0.3560 MB
# Global model accuracy after round 1: 0.6227
# Round 2/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 2: 0.3560 MB
# Global model accuracy after round 2: 0.7189
# Convergence achieved at round 2 with accuracy 0.7189
# Convergence time: 476.49 seconds
# Round 3/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 3: 0.3560 MB
# Global model accuracy after round 3: 0.7498
# Round 4/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 4: 0.3560 MB
# Global model accuracy after round 4: 0.7713
# Round 5/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 5: 0.3560 MB
# Global model accuracy after round 5: 0.7873
# Round 6/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 6: 0.3560 MB
# Global model accuracy after round 6: 0.8020
# Round 7/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 7: 0.3560 MB
# Global model accuracy after round 7: 0.8109
# Round 8/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 8: 0.3560 MB
# Global model accuracy after round 8: 0.8203
# Round 9/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 9: 0.3560 MB
# Global model accuracy after round 9: 0.8273
# Round 10/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 10: 0.3560 MB
# Global model accuracy after round 10: 0.8323
# Round 11/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 11: 0.3560 MB
# Global model accuracy after round 11: 0.8385
# Round 12/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 12: 0.3560 MB
# Global model accuracy after round 12: 0.8440
# Round 13/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 13: 0.3560 MB
# Global model accuracy after round 13: 0.8489
# Round 14/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 14: 0.3560 MB
# Global model accuracy after round 14: 0.8524
# Round 15/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 15: 0.3560 MB
# Global model accuracy after round 15: 0.8546
# Round 16/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 16: 0.3560 MB
# Global model accuracy after round 16: 0.8585
# Round 17/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 17: 0.3560 MB
# Global model accuracy after round 17: 0.8593
# Round 18/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 18: 0.3560 MB
# Global model accuracy after round 18: 0.8618
# Round 19/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 19: 0.3560 MB
# Global model accuracy after round 19: 0.8647
# Round 20/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 20: 0.3560 MB
# Global model accuracy after round 20: 0.8672
# Round 21/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# ...
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 24: 0.3560 MB
# Global model accuracy after round 24: 0.8753
# Round 25/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 25: 0.3560 MB
# Global model accuracy after round 25: 0.8771
# Round 26/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 26: 0.3560 MB
# Global model accuracy after round 26: 0.8785
# Round 27/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 27: 0.3560 MB
# Global model accuracy after round 27: 0.8797
# Round 28/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 28: 0.3560 MB
# Global model accuracy after round 28: 0.8806
# Round 29/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 29: 0.3560 MB
# Global model accuracy after round 29: 0.8826
# Round 30/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 30: 0.3560 MB
# Global model accuracy after round 30: 0.8845
# Final global model accuracy: 0.8845
# Total communication overhead: 10.6799 MB
# Convergence achieved at round 2 with accuracy 0.8845
# Convergence time: 476.49 seconds

# %% [markdown]
# **CENTRALIZED EXPERIMENT**

# %%
import tensorflow as tf
import numpy as np
import time
import matplotlib.pyplot as plt

# Load and preprocess the FashionMNIST dataset
def load_and_preprocess_data():
    (x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

    # Preprocessing: normalize to [0,1] and reshape to (28, 28, 1)
    x_train = x_train.astype('float32') / 255.0
    x_test = x_test.astype('float32') / 255.0
    x_train = np.expand_dims(x_train, axis=-1)
    x_test = np.expand_dims(x_test, axis=-1)

    # One-hot encode labels
    y_train = tf.keras.utils.to_categorical(y_train, num_classes=10)
    y_test = tf.keras.utils.to_categorical(y_test, num_classes=10)

    return (x_train, y_train), (x_test, y_test)

# Define the global CNN model
def create_cnn_model():
    model = tf.keras.Sequential([
        tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(10, activation='softmax')
    ])
    return model

# Load and preprocess data
(x_train, y_train), (x_test, y_test) = load_and_preprocess_data()

# Create and compile the model
model = create_cnn_model()
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
start_time = time.time()
history = model.fit(x_train, y_train, epochs=30, batch_size=32, validation_data=(x_test, y_test), verbose=1)
training_time = time.time() - start_time

# Evaluate the model
final_loss, final_accuracy = model.evaluate(x_test, y_test, verbose=0)
print(f"Final model accuracy: {final_accuracy:.4f}")
print(f"Training time: {training_time:.2f} seconds")

# Visualization
plt.figure(figsize=(12, 6))

# Plot accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='test')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 28s 14ms/step - accuracy: 0.7389 - loss: 0.7124 - val_accuracy: 0.8593 - val_loss: 0.3735
# Epoch 2/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 25s 13ms/step - accuracy: 0.8796 - loss: 0.3314 - val_accuracy: 0.8862 - val_loss: 0.3202
# Epoch 3/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 23s 12ms/step - accuracy: 0.8994 - loss: 0.2729 - val_accuracy: 0.8943 - val_loss: 0.2891
# Epoch 4/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 23s 12ms/step - accuracy: 0.9082 - loss: 0.2488 - val_accuracy: 0.8891 - val_loss: 0.3010
# Epoch 5/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 25s 13ms/step - accuracy: 0.9193 - loss: 0.2257 - val_accuracy: 0.9010 - val_loss: 0.2711
# Epoch 6/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 23s 12ms/step - accuracy: 0.9250 - loss: 0.2042 - val_accuracy: 0.9062 - val_loss: 0.2611
# Epoch 7/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 24s 13ms/step - accuracy: 0.9337 - loss: 0.1822 - val_accuracy: 0.9089 - val_loss: 0.2558
# Epoch 8/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 23s 12ms/step - accuracy: 0.9374 - loss: 0.1688 - val_accuracy: 0.9110 - val_loss: 0.2516
# Epoch 9/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 24s 13ms/step - accuracy: 0.9432 - loss: 0.1527 - val_accuracy: 0.9092 - val_loss: 0.2700
# Epoch 10/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 24s 13ms/step - accuracy: 0.9480 - loss: 0.1388 - val_accuracy: 0.9119 - val_loss: 0.2641
# Epoch 11/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 24s 13ms/step - accuracy: 0.9522 - loss: 0.1303 - val_accuracy: 0.9133 - val_loss: 0.2873
# Epoch 12/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 24s 13ms/step - accuracy: 0.9568 - loss: 0.1157 - val_accuracy: 0.9119 - val_loss: 0.2954
# Epoch 13/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 24s 13ms/step - accuracy: 0.9590 - loss: 0.1095 - val_accuracy: 0.9095 - val_loss: 0.3140
# Epoch 14/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 24s 13ms/step - accuracy: 0.9632 - loss: 0.0997 - val_accuracy: 0.9025 - val_loss: 0.3466
# Epoch 15/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 25s 13ms/step - accuracy: 0.9648 - loss: 0.0920 - val_accuracy: 0.9049 - val_loss: 0.3524
# Epoch 16/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 24s 13ms/step - accuracy: 0.9676 - loss: 0.0848 - val_accuracy: 0.9021 - val_loss: 0.3405
# Epoch 17/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 23s 12ms/step - accuracy: 0.9696 - loss: 0.0798 - val_accuracy: 0.9015 - val_loss: 0.4059
# Epoch 18/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 23s 12ms/step - accuracy: 0.9709 - loss: 0.0772 - val_accuracy: 0.9075 - val_loss: 0.3725
# Epoch 19/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 23s 12ms/step - accuracy: 0.9727 - loss: 0.0724 - val_accuracy: 0.9044 - val_loss: 0.3960
# Epoch 20/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 24s 13ms/step - accuracy: 0.9761 - loss: 0.0632 - val_accuracy: 0.9077 - val_loss: 0.3775
# Epoch 21/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 23s 13ms/step - accuracy: 0.9781 - loss: 0.0583 - val_accuracy: 0.9068 - val_loss: 0.4351
# Epoch 22/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 24s 13ms/step - accuracy: 0.9761 - loss: 0.0611 - val_accuracy: 0.9065 - val_loss: 0.4247
# Epoch 23/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 24s 13ms/step - accuracy: 0.9799 - loss: 0.0546 - val_accuracy: 0.9051 - val_loss: 0.4681
# Epoch 24/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 24s 13ms/step - accuracy: 0.9794 - loss: 0.0539 - val_accuracy: 0.9062 - val_loss: 0.4811
# Epoch 25/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 24s 13ms/step - accuracy: 0.9822 - loss: 0.0469 - val_accuracy: 0.9051 - val_loss: 0.5033
# Epoch 26/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 24s 13ms/step - accuracy: 0.9794 - loss: 0.0533 - val_accuracy: 0.9036 - val_loss: 0.5475
# Epoch 27/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 24s 13ms/step - accuracy: 0.9807 - loss: 0.0507 - val_accuracy: 0.9040 - val_loss: 0.5297
# Epoch 28/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 23s 12ms/step - accuracy: 0.9798 - loss: 0.0546 - val_accuracy: 0.9004 - val_loss: 0.5426
# Epoch 29/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 23s 12ms/step - accuracy: 0.9848 - loss: 0.0412 - val_accuracy: 0.9046 - val_loss: 0.5719
# Epoch 30/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 24s 13ms/step - accuracy: 0.9862 - loss: 0.0383 - val_accuracy: 0.9000 - val_loss: 0.5671
# Final model accuracy: 0.9000
# Training time: 716.74 seconds
