# %% [markdown]
# **EXPERIMENT ONE**

# %%
import tensorflow as tf
import numpy as np
import time
import matplotlib.pyplot as plt

# Loading  and preprocessing  the CIFAR-10 dataset
def load_and_preprocess_data():
    (x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

    # Preprocessing: normalizing to [0,1]
    x_train = x_train.astype('float32') / 255.0
    x_test = x_test.astype('float32') / 255.0

    # One-hot encoding labels
    y_train = tf.keras.utils.to_categorical(y_train, num_classes=10)
    y_test = tf.keras.utils.to_categorical(y_test, num_classes=10)

    return (x_train, y_train), (x_test, y_test)

# Define the global CNN model
def create_cnn_model():
    model = tf.keras.Sequential([
        tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(10, activation='softmax')
    ])
    return model

# Create federated data by splitting the dataset among clients
def create_federated_data(x, y, num_clients=10):
    client_data = []
    data_per_client = len(x) // num_clients
    for i in range(num_clients):
        client_x = x[i * data_per_client:(i + 1) * data_per_client]
        client_y = y[i * data_per_client:(i + 1) * data_per_client]
        client_data.append((client_x, client_y))
    return client_data

# Measure communication overhead
def measure_communication_overhead(weights):
    return sum([np.prod(w.shape) for w in weights]) * 4 / (1024 * 1024)  # in MB

# Federated learning parameters
num_clients = 10
num_rounds = 30
local_epochs = 3
accuracy_threshold = 0.70  # Define an accuracy threshold for convergence speed

# Load and preprocess data
(x_train, y_train), (x_test, y_test) = load_and_preprocess_data()

# Create federated data for each client
federated_train_data = create_federated_data(x_train, y_train, num_clients)

# Create global model
global_model = create_cnn_model()
global_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Initialize variables to measure communication overhead and convergence speed
total_communication_overhead = 0
convergence_round = None
start_time = time.time()

# Lists to store metrics for visualization
communication_overheads = []
accuracies = []
round_times = []

# Federated learning loop
for round_num in range(num_rounds):
    print(f"Round {round_num + 1}/{num_rounds}")

    local_weights = []
    round_start_time = time.time()

    # Train on each client
    for client_id in range(num_clients):
        print(f"Training on client {client_id + 1}")

        # Create local model and set global weights
        local_model = create_cnn_model()
        local_model.set_weights(global_model.get_weights())
        local_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

        # Get client data
        X, y = federated_train_data[client_id]

        # Train local model
        local_model.fit(X, y, epochs=local_epochs, batch_size=32, verbose=0)

        # Collect local model weights
        local_weights.append(local_model.get_weights())

    # Federated averaging: Aggregate local weights
    averaged_weights = [np.mean([local_weights[j][i] for j in range(num_clients)], axis=0)
                        for i in range(len(local_weights[0]))]

    # Measure communication overhead
    round_communication_overhead = measure_communication_overhead(averaged_weights)
    total_communication_overhead += round_communication_overhead
    communication_overheads.append(round_communication_overhead)
    print(f"Communication overhead for round {round_num + 1}: {round_communication_overhead:.4f} MB")

    # Update global model weights
    global_model.set_weights(averaged_weights)

    # Evaluate the global model
    loss, accuracy = global_model.evaluate(x_test, y_test, verbose=0)
    accuracies.append(accuracy)
    print(f"Global model accuracy after round {round_num + 1}: {accuracy:.4f}")

    # Check for convergence
    if convergence_round is None and accuracy >= accuracy_threshold:
        convergence_round = round_num + 1
        convergence_time = time.time() - start_time
        print(f"Convergence achieved at round {convergence_round} with accuracy {accuracy:.4f}")
        print(f"Convergence time: {convergence_time:.2f} seconds")

    # Record round time
    round_time = time.time() - round_start_time
    round_times.append(round_time)

# Evaluate the final global model
final_loss, final_accuracy = global_model.evaluate(x_test, y_test, verbose=0)
print(f"Final global model accuracy: {final_accuracy:.4f}")

# Print total communication overhead
print(f"Total communication overhead: {total_communication_overhead:.4f} MB")

# Print convergence information if not already printed
if convergence_round is None:
    convergence_time = time.time() - start_time
    print(f"Convergence not achieved within {num_rounds} rounds.")
else:
    print(f"Convergence achieved at round {convergence_round} with accuracy {final_accuracy:.4f}")
    print(f"Convergence time: {convergence_time:.2f} seconds")

# Visualization
rounds = list(range(1, num_rounds + 1))

plt.figure(figsize=(12, 6))

# Plot communication overhead
plt.subplot(1, 3, 1)
plt.plot(rounds, communication_overheads, marker='o')
plt.title('Communication Overhead per Round')
plt.xlabel('Round')
plt.ylabel('Communication Overhead (MB)')

# Plot accuracy
plt.subplot(1, 3, 2)
plt.plot(rounds, accuracies, marker='o')
plt.title('Global Model Accuracy per Round')
plt.xlabel('Round')
plt.ylabel('Accuracy')

# Plot round times
plt.subplot(1, 3, 3)
plt.plot(rounds, round_times, marker='o')
plt.title('Round Time')
plt.xlabel('Round')
plt.ylabel('Time (seconds)')

plt.tight_layout()
plt.show()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Round 1/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 1: 0.4676 MB
# Global model accuracy after round 1: 0.3574
# Round 2/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 2: 0.4676 MB
# Global model accuracy after round 2: 0.5229
# Round 3/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 3: 0.4676 MB
# Global model accuracy after round 3: 0.5768
# Round 4/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 4: 0.4676 MB
# Global model accuracy after round 4: 0.6136
# Round 5/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 5: 0.4676 MB
# Global model accuracy after round 5: 0.6401
# Round 6/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 6: 0.4676 MB
# Global model accuracy after round 6: 0.6626
# Round 7/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 7: 0.4676 MB
# Global model accuracy after round 7: 0.6747
# Round 8/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 8: 0.4676 MB
# Global model accuracy after round 8: 0.6829
# Round 9/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 9: 0.4676 MB
# Global model accuracy after round 9: 0.6916
# Round 10/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 10: 0.4676 MB
# Global model accuracy after round 10: 0.6981
# Round 11/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 11: 0.4676 MB
# Global model accuracy after round 11: 0.7028
# Convergence achieved at round 11 with accuracy 0.7028
# Convergence time: 3111.30 seconds
# Round 12/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 12: 0.4676 MB
# Global model accuracy after round 12: 0.7028
# Round 13/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 13: 0.4676 MB
# Global model accuracy after round 13: 0.7058
# Round 14/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 14: 0.4676 MB
# Global model accuracy after round 14: 0.7100
# Round 15/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 15: 0.4676 MB
# Global model accuracy after round 15: 0.7106
# Round 16/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 16: 0.4676 MB
# Global model accuracy after round 16: 0.7146
# Round 17/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 17: 0.4676 MB
# Global model accuracy after round 17: 0.7147
# Round 18/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 18: 0.4676 MB
# Global model accuracy after round 18: 0.7142
# Round 19/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 19: 0.4676 MB
# Global model accuracy after round 19: 0.7133
# Round 20/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 20: 0.4676 MB
# Global model accuracy after round 20: 0.7101
# Round 21/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 21: 0.4676 MB
# Global model accuracy after round 21: 0.7120
# Round 22/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 22: 0.4676 MB
# Global model accuracy after round 22: 0.7083
# Round 23/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 23: 0.4676 MB
# Global model accuracy after round 23: 0.7092
# Round 24/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 24: 0.4676 MB
# Global model accuracy after round 24: 0.7090
# Round 25/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 25: 0.4676 MB
# Global model accuracy after round 25: 0.7096
# Round 26/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 26: 0.4676 MB
# Global model accuracy after round 26: 0.7092
# Round 27/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 27: 0.4676 MB
# Global model accuracy after round 27: 0.7101
# Round 28/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 28: 0.4676 MB
# Global model accuracy after round 28: 0.7086
# Round 29/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 29: 0.4676 MB
# Global model accuracy after round 29: 0.7089
# Round 30/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Communication overhead for round 30: 0.4676 MB
# Global model accuracy after round 30: 0.7108
# Final global model accuracy: 0.7108
# Total communication overhead: 14.0270 MB
# Convergence achieved at round 11 with accuracy 0.7108
# Convergence time: 3111.30 seconds

# %% [markdown]
# **EXPERIMENT TWO**

# %%
import tensorflow as tf
import numpy as np
import time
import matplotlib.pyplot as plt

# Load and preprocess the CIFAR-10 dataset
def load_and_preprocess_data():
    (x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

    # Preprocessing: normalize to [0,1]
    x_train = x_train.astype('float32') / 255.0
    x_test = x_test.astype('float32') / 255.0

    # One-hot encode labels
    y_train = tf.keras.utils.to_categorical(y_train, num_classes=10)
    y_test = tf.keras.utils.to_categorical(y_test, num_classes=10)

    return (x_train, y_train), (x_test, y_test)

# Define the global CNN model
def create_cnn_model():
    model = tf.keras.Sequential([
        tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(10, activation='softmax')
    ])
    return model

# Create federated data by splitting the dataset among clients
def create_federated_data(x, y, num_clients=10):
    client_data = []
    data_per_client = len(x) // num_clients
    for i in range(num_clients):
        client_x = x[i * data_per_client:(i + 1) * data_per_client]
        client_y = y[i * data_per_client:(i + 1) * data_per_client]
        client_data.append((client_x, client_y))
    return client_data

# Measure communication overhead
def measure_communication_overhead(weights):
    return sum([np.prod(w.shape) for w in weights]) * 4 / (1024 * 1024)  # in MB

# Federated learning parameters
num_clients = 20
num_rounds = 30
local_epochs = 3
accuracy_threshold = 0.70  # Define an accuracy threshold for convergence speed

# Load and preprocess data
(x_train, y_train), (x_test, y_test) = load_and_preprocess_data()

# Create federated data for each client
federated_train_data = create_federated_data(x_train, y_train, num_clients)

# Create global model
global_model = create_cnn_model()
global_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Initialize variables to measure communication overhead and convergence speed
total_communication_overhead = 0
convergence_round = None
start_time = time.time()

# Lists to store metrics for visualization
communication_overheads = []
accuracies = []
round_times = []

# Federated learning loop
for round_num in range(num_rounds):
    print(f"Round {round_num + 1}/{num_rounds}")

    local_weights = []
    round_start_time = time.time()

    # Train on each client
    for client_id in range(num_clients):
        print(f"Training on client {client_id + 1}")

        # Create local model and set global weights
        local_model = create_cnn_model()
        local_model.set_weights(global_model.get_weights())
        local_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

        # Get client data
        X, y = federated_train_data[client_id]

        # Train local model
        local_model.fit(X, y, epochs=local_epochs, batch_size=32, verbose=0)

        # Collect local model weights
        local_weights.append(local_model.get_weights())

    # Federated averaging: Aggregate local weights
    averaged_weights = [np.mean([local_weights[j][i] for j in range(num_clients)], axis=0)
                        for i in range(len(local_weights[0]))]

    # Measure communication overhead
    round_communication_overhead = measure_communication_overhead(averaged_weights)
    total_communication_overhead += round_communication_overhead
    communication_overheads.append(round_communication_overhead)
    print(f"Communication overhead for round {round_num + 1}: {round_communication_overhead:.4f} MB")

    # Update global model weights
    global_model.set_weights(averaged_weights)

    # Evaluate the global model
    loss, accuracy = global_model.evaluate(x_test, y_test, verbose=0)
    accuracies.append(accuracy)
    print(f"Global model accuracy after round {round_num + 1}: {accuracy:.4f}")

    # Check for convergence
    if convergence_round is None and accuracy >= accuracy_threshold:
        convergence_round = round_num + 1
        convergence_time = time.time() - start_time
        print(f"Convergence achieved at round {convergence_round} with accuracy {accuracy:.4f}")
        print(f"Convergence time: {convergence_time:.2f} seconds")

    # Record round time
    round_time = time.time() - round_start_time
    round_times.append(round_time)

# Evaluate the final global model
final_loss, final_accuracy = global_model.evaluate(x_test, y_test, verbose=0)
print(f"Final global model accuracy: {final_accuracy:.4f}")

# Print total communication overhead
print(f"Total communication overhead: {total_communication_overhead:.4f} MB")

# Print convergence information if not already printed
if convergence_round is None:
    convergence_time = time.time() - start_time
    print(f"Convergence not achieved within {num_rounds} rounds.")
else:
    print(f"Convergence achieved at round {convergence_round} with accuracy {final_accuracy:.4f}")
    print(f"Convergence time: {convergence_time:.2f} seconds")

# Visualization
rounds = list(range(1, num_rounds + 1))

plt.figure(figsize=(12, 6))

# Plot communication overhead
plt.subplot(1, 3, 1)
plt.plot(rounds, communication_overheads, marker='o')
plt.title('Communication Overhead per Round')
plt.xlabel('Round')
plt.ylabel('Communication Overhead (MB)')

# Plot accuracy
plt.subplot(1, 3, 2)
plt.plot(rounds, accuracies, marker='o')
plt.title('Global Model Accuracy per Round')
plt.xlabel('Round')
plt.ylabel('Accuracy')

# Plot round times
plt.subplot(1, 3, 3)
plt.plot(rounds, round_times, marker='o')
plt.title('Round Time')
plt.xlabel('Round')
plt.ylabel('Time (seconds)')

plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Round 1/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 1: 0.4676 MB
# Global model accuracy after round 1: 0.2883
# Round 2/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 2: 0.4676 MB
# Global model accuracy after round 2: 0.4444
# Round 3/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 3: 0.4676 MB
# Global model accuracy after round 3: 0.5125
# Round 4/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 4: 0.4676 MB
# Global model accuracy after round 4: 0.5404
# Round 5/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 5: 0.4676 MB
# Global model accuracy after round 5: 0.5693
# Round 6/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 6: 0.4676 MB
# Global model accuracy after round 6: 0.5902
# Round 7/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 7: 0.4676 MB
# Global model accuracy after round 7: 0.6065
# Round 8/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 8: 0.4676 MB
# Global model accuracy after round 8: 0.6252
# Round 9/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 9: 0.4676 MB
# Global model accuracy after round 9: 0.6410
# Round 10/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 10: 0.4676 MB
# Global model accuracy after round 10: 0.6462
# Round 11/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 11: 0.4676 MB
# Global model accuracy after round 11: 0.6538
# Round 12/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 12: 0.4676 MB
# Global model accuracy after round 12: 0.6643
# Round 13/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 13: 0.4676 MB
# Global model accuracy after round 13: 0.6680
# Round 14/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 14: 0.4676 MB
# Global model accuracy after round 14: 0.6758
# Round 15/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 15: 0.4676 MB
# Global model accuracy after round 15: 0.6813
# Round 16/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 16: 0.4676 MB
# Global model accuracy after round 16: 0.6862
# Round 17/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 17: 0.4676 MB
# Global model accuracy after round 17: 0.6867
# Round 18/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 18: 0.4676 MB
# Global model accuracy after round 18: 0.6912
# Round 19/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 19: 0.4676 MB
# Global model accuracy after round 19: 0.6957
# Round 20/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 20: 0.4676 MB
# Global model accuracy after round 20: 0.6989
# Round 21/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 21: 0.4676 MB
# Global model accuracy after round 21: 0.6970
# Round 22/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 22: 0.4676 MB
# Global model accuracy after round 22: 0.6988
# Round 23/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 23: 0.4676 MB
# Global model accuracy after round 23: 0.6989
# Round 24/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 24: 0.4676 MB
# Global model accuracy after round 24: 0.7030
# Convergence achieved at round 24 with accuracy 0.7030
# Convergence time: 7475.03 seconds
# Round 25/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 25: 0.4676 MB
# Global model accuracy after round 25: 0.7018
# Round 26/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 26: 0.4676 MB
# Global model accuracy after round 26: 0.6984
# Round 27/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 27: 0.4676 MB
# Global model accuracy after round 27: 0.7039
# Round 28/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 28: 0.4676 MB
# Global model accuracy after round 28: 0.7045
# Round 29/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 29: 0.4676 MB
# Global model accuracy after round 29: 0.7043
# Round 30/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Communication overhead for round 30: 0.4676 MB
# Global model accuracy after round 30: 0.7051
# Final global model accuracy: 0.7051
# Total communication overhead: 14.0270 MB
# Convergence achieved at round 24 with accuracy 0.7051
# Convergence time: 7475.03 seconds

# %% [markdown]
# **EXPERIMENT THREE**

# %%
import tensorflow as tf
import numpy as np
import time
import matplotlib.pyplot as plt

# Load and preprocess the CIFAR-10 dataset
def load_and_preprocess_data():
    (x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

    # Preprocessing: normalize to [0,1]
    x_train = x_train.astype('float32') / 255.0
    x_test = x_test.astype('float32') / 255.0

    # One-hot encode labels
    y_train = tf.keras.utils.to_categorical(y_train, num_classes=10)
    y_test = tf.keras.utils.to_categorical(y_test, num_classes=10)

    return (x_train, y_train), (x_test, y_test)

# Define the global CNN model
def create_cnn_model():
    model = tf.keras.Sequential([
        tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(10, activation='softmax')
    ])
    return model

# Create federated data by splitting the dataset among clients
def create_federated_data(x, y, num_clients=10):
    client_data = []
    data_per_client = len(x) // num_clients
    for i in range(num_clients):
        client_x = x[i * data_per_client:(i + 1) * data_per_client]
        client_y = y[i * data_per_client:(i + 1) * data_per_client]
        client_data.append((client_x, client_y))
    return client_data

# Measure communication overhead
def measure_communication_overhead(weights):
    return sum([np.prod(w.shape) for w in weights]) * 4 / (1024 * 1024)  # in MB

# Federated learning parameters
num_clients = 30
num_rounds = 30
local_epochs = 3
accuracy_threshold = 0.70  # Define an accuracy threshold for convergence speed

# Load and preprocess data
(x_train, y_train), (x_test, y_test) = load_and_preprocess_data()

# Create federated data for each client
federated_train_data = create_federated_data(x_train, y_train, num_clients)

# Create global model
global_model = create_cnn_model()
global_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Initialize variables to measure communication overhead and convergence speed
total_communication_overhead = 0
convergence_round = None
start_time = time.time()

# Lists to store metrics for visualization
communication_overheads = []
accuracies = []
round_times = []

# Federated learning loop
for round_num in range(num_rounds):
    print(f"Round {round_num + 1}/{num_rounds}")

    local_weights = []
    round_start_time = time.time()

    # Train on each client
    for client_id in range(num_clients):
        print(f"Training on client {client_id + 1}")

        # Create local model and set global weights
        local_model = create_cnn_model()
        local_model.set_weights(global_model.get_weights())
        local_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

        # Get client data
        X, y = federated_train_data[client_id]

        # Train local model
        local_model.fit(X, y, epochs=local_epochs, batch_size=32, verbose=0)

        # Collect local model weights
        local_weights.append(local_model.get_weights())

    # Federated averaging: Aggregate local weights
    averaged_weights = [np.mean([local_weights[j][i] for j in range(num_clients)], axis=0)
                        for i in range(len(local_weights[0]))]

    # Measure communication overhead
    round_communication_overhead = measure_communication_overhead(averaged_weights)
    total_communication_overhead += round_communication_overhead
    communication_overheads.append(round_communication_overhead)
    print(f"Communication overhead for round {round_num + 1}: {round_communication_overhead:.4f} MB")

    # Update global model weights
    global_model.set_weights(averaged_weights)

    # Evaluate the global model
    loss, accuracy = global_model.evaluate(x_test, y_test, verbose=0)
    accuracies.append(accuracy)
    print(f"Global model accuracy after round {round_num + 1}: {accuracy:.4f}")

    # Check for convergence
    if convergence_round is None and accuracy >= accuracy_threshold:
        convergence_round = round_num + 1
        convergence_time = time.time() - start_time
        print(f"Convergence achieved at round {convergence_round} with accuracy {accuracy:.4f}")
        print(f"Convergence time: {convergence_time:.2f} seconds")

    # Record round time
    round_time = time.time() - round_start_time
    round_times.append(round_time)

# Evaluate the final global model
final_loss, final_accuracy = global_model.evaluate(x_test, y_test, verbose=0)
print(f"Final global model accuracy: {final_accuracy:.4f}")

# Print total communication overhead
print(f"Total communication overhead: {total_communication_overhead:.4f} MB")

# Print convergence information if not already printed
if convergence_round is None:
    convergence_time = time.time() - start_time
    print(f"Convergence not achieved within {num_rounds} rounds.")
else:
    print(f"Convergence achieved at round {convergence_round} with accuracy {final_accuracy:.4f}")
    print(f"Convergence time: {convergence_time:.2f} seconds")

# Visualization
rounds = list(range(1, num_rounds + 1))

plt.figure(figsize=(12, 6))

# Plot communication overhead
plt.subplot(1, 3, 1)
plt.plot(rounds, communication_overheads, marker='o')
plt.title('Communication Overhead per Round')
plt.xlabel('Round')
plt.ylabel('Communication Overhead (MB)')

# Plot accuracy
plt.subplot(1, 3, 2)
plt.plot(rounds, accuracies, marker='o')
plt.title('Global Model Accuracy per Round')
plt.xlabel('Round')
plt.ylabel('Accuracy')

# Plot round times
plt.subplot(1, 3, 3)
plt.plot(rounds, round_times, marker='o')
plt.title('Round Time')
plt.xlabel('Round')
plt.ylabel('Time (seconds)')

plt.tight_layout()
plt.show()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Round 1/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Communication overhead for round 1: 0.4676 MB
# Global model accuracy after round 1: 0.2214
# Round 2/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Communication overhead for round 2: 0.4676 MB
# Global model accuracy after round 2: 0.3945
# Round 3/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Communication overhead for round 3: 0.4676 MB
# Global model accuracy after round 3: 0.4580
# Round 4/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Communication overhead for round 4: 0.4676 MB
# Global model accuracy after round 4: 0.4930
# Round 5/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Communication overhead for round 5: 0.4676 MB
# Global model accuracy after round 5: 0.5183
# Round 6/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Communication overhead for round 6: 0.4676 MB
# Global model accuracy after round 6: 0.5401
# Round 7/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Communication overhead for round 7: 0.4676 MB
# Global model accuracy after round 7: 0.5609
# Round 8/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Communication overhead for round 8: 0.4676 MB
# Global model accuracy after round 8: 0.5718
# Round 9/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Communication overhead for round 9: 0.4676 MB
# Global model accuracy after round 9: 0.5913
# Round 10/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Communication overhead for round 10: 0.4676 MB
# Global model accuracy after round 10: 0.6048
# Round 11/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Communication overhead for round 11: 0.4676 MB
# Global model accuracy after round 11: 0.6162
# Round 12/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Communication overhead for round 12: 0.4676 MB
# Global model accuracy after round 12: 0.6266
# Round 13/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Communication overhead for round 13: 0.4676 MB
# Global model accuracy after round 13: 0.6369
# Round 14/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Communication overhead for round 14: 0.4676 MB
# Global model accuracy after round 14: 0.6437
# Round 15/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Communication overhead for round 15: 0.4676 MB
# Global model accuracy after round 15: 0.6502
# Round 16/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Communication overhead for round 16: 0.4676 MB
# Global model accuracy after round 16: 0.6566
# Round 17/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Communication overhead for round 17: 0.4676 MB
# Global model accuracy after round 17: 0.6602
# Round 18/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Communication overhead for round 18: 0.4676 MB
# Global model accuracy after round 18: 0.6659
# Round 19/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Communication overhead for round 19: 0.4676 MB
# Global model accuracy after round 19: 0.6690
# Round 20/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Communication overhead for round 20: 0.4676 MB
# Global model accuracy after round 20: 0.6720
# Round 21/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Communication overhead for round 21: 0.4676 MB
# Global model accuracy after round 21: 0.6747
# Round 22/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Communication overhead for round 22: 0.4676 MB
# Global model accuracy after round 22: 0.6801
# Round 23/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Communication overhead for round 23: 0.4676 MB
# Global model accuracy after round 23: 0.6829
# Round 24/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Communication overhead for round 24: 0.4676 MB
# Global model accuracy after round 24: 0.6853
# Round 25/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Communication overhead for round 25: 0.4676 MB
# Global model accuracy after round 25: 0.6875
# Round 26/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Communication overhead for round 26: 0.4676 MB
# Global model accuracy after round 26: 0.6895
# Round 27/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Communication overhead for round 27: 0.4676 MB
# Global model accuracy after round 27: 0.6918
# Round 28/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Communication overhead for round 28: 0.4676 MB
# Global model accuracy after round 28: 0.6901
# Round 29/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Communication overhead for round 29: 0.4676 MB
# Global model accuracy after round 29: 0.6940
# Round 30/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Communication overhead for round 30: 0.4676 MB
# Global model accuracy after round 30: 0.6958
# Final global model accuracy: 0.6958
# Total communication overhead: 14.0270 MB
# Convergence not achieved within 30 rounds.

# %% [markdown]
# **EXPERIMENT FOUR**

# %%
import tensorflow as tf
import numpy as np
import time
import matplotlib.pyplot as plt

# Load and preprocess the CIFAR-10 dataset
def load_and_preprocess_data():
    (x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

    # Preprocessing: normalize to [0,1]
    x_train = x_train.astype('float32') / 255.0
    x_test = x_test.astype('float32') / 255.0

    # One-hot encode labels
    y_train = tf.keras.utils.to_categorical(y_train, num_classes=10)
    y_test = tf.keras.utils.to_categorical(y_test, num_classes=10)

    return (x_train, y_train), (x_test, y_test)

# Define the global CNN model
def create_cnn_model():
    model = tf.keras.Sequential([
        tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(10, activation='softmax')
    ])
    return model

# Create federated data by splitting the dataset among clients
def create_federated_data(x, y, num_clients=10):
    client_data = []
    data_per_client = len(x) // num_clients
    for i in range(num_clients):
        client_x = x[i * data_per_client:(i + 1) * data_per_client]
        client_y = y[i * data_per_client:(i + 1) * data_per_client]
        client_data.append((client_x, client_y))
    return client_data

# Measure communication overhead
def measure_communication_overhead(weights):
    return sum([np.prod(w.shape) for w in weights]) * 4 / (1024 * 1024)  # in MB

# Federated learning parameters
num_clients = 40
num_rounds = 30
local_epochs = 3
accuracy_threshold = 0.70  # Define an accuracy threshold for convergence speed

# Load and preprocess data
(x_train, y_train), (x_test, y_test) = load_and_preprocess_data()

# Create federated data for each client
federated_train_data = create_federated_data(x_train, y_train, num_clients)

# Create global model
global_model = create_cnn_model()
global_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Initialize variables to measure communication overhead and convergence speed
total_communication_overhead = 0
convergence_round = None
start_time = time.time()

# Lists to store metrics for visualization
communication_overheads = []
accuracies = []
round_times = []

# Federated learning loop
for round_num in range(num_rounds):
    print(f"Round {round_num + 1}/{num_rounds}")

    local_weights = []
    round_start_time = time.time()

    # Train on each client
    for client_id in range(num_clients):
        print(f"Training on client {client_id + 1}")

        # Create local model and set global weights
        local_model = create_cnn_model()
        local_model.set_weights(global_model.get_weights())
        local_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

        # Get client data
        X, y = federated_train_data[client_id]

        # Train local model
        local_model.fit(X, y, epochs=local_epochs, batch_size=32, verbose=0)

        # Collect local model weights
        local_weights.append(local_model.get_weights())

    # Federated averaging: Aggregate local weights
    averaged_weights = [np.mean([local_weights[j][i] for j in range(num_clients)], axis=0)
                        for i in range(len(local_weights[0]))]

    # Measure communication overhead
    round_communication_overhead = measure_communication_overhead(averaged_weights)
    total_communication_overhead += round_communication_overhead
    communication_overheads.append(round_communication_overhead)
    print(f"Communication overhead for round {round_num + 1}: {round_communication_overhead:.4f} MB")

    # Update global model weights
    global_model.set_weights(averaged_weights)

    # Evaluate the global model
    loss, accuracy = global_model.evaluate(x_test, y_test, verbose=0)
    accuracies.append(accuracy)
    print(f"Global model accuracy after round {round_num + 1}: {accuracy:.4f}")

    # Check for convergence
    if convergence_round is None and accuracy >= accuracy_threshold:
        convergence_round = round_num + 1
        convergence_time = time.time() - start_time
        print(f"Convergence achieved at round {convergence_round} with accuracy {accuracy:.4f}")
        print(f"Convergence time: {convergence_time:.2f} seconds")

    # Record round time
    round_time = time.time() - round_start_time
    round_times.append(round_time)

# Evaluate the final global model
final_loss, final_accuracy = global_model.evaluate(x_test, y_test, verbose=0)
print(f"Final global model accuracy: {final_accuracy:.4f}")

# Print total communication overhead
print(f"Total communication overhead: {total_communication_overhead:.4f} MB")

# Print convergence information if not already printed
if convergence_round is None:
    convergence_time = time.time() - start_time
    print(f"Convergence not achieved within {num_rounds} rounds.")
else:
    print(f"Convergence achieved at round {convergence_round} with accuracy {final_accuracy:.4f}")
    print(f"Convergence time: {convergence_time:.2f} seconds")

# Visualization
rounds = list(range(1, num_rounds + 1))

plt.figure(figsize=(12, 6))

# Plot communication overhead
plt.subplot(1, 3, 1)
plt.plot(rounds, communication_overheads, marker='o')
plt.title('Communication Overhead per Round')
plt.xlabel('Round')
plt.ylabel('Communication Overhead (MB)')

# Plot accuracy
plt.subplot(1, 3, 2)
plt.plot(rounds, accuracies, marker='o')
plt.title('Global Model Accuracy per Round')
plt.xlabel('Round')
plt.ylabel('Accuracy')

# Plot round times
plt.subplot(1, 3, 3)
plt.plot(rounds, round_times, marker='o')
plt.title('Round Time')
plt.xlabel('Round')
plt.ylabel('Time (seconds)')

plt.tight_layout()
plt.show()
# Out:
# Round 1/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Communication overhead for round 1: 0.4676 MB
# Global model accuracy after round 1: 0.2502
# Round 2/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Communication overhead for round 2: 0.4676 MB
# Global model accuracy after round 2: 0.3743
# Round 3/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Communication overhead for round 3: 0.4676 MB
# Global model accuracy after round 3: 0.4279
# Round 4/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Communication overhead for round 4: 0.4676 MB
# Global model accuracy after round 4: 0.4627
# Round 5/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Communication overhead for round 5: 0.4676 MB
# Global model accuracy after round 5: 0.4948
# Round 6/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Communication overhead for round 6: 0.4676 MB
# Global model accuracy after round 6: 0.5143
# Round 7/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Communication overhead for round 7: 0.4676 MB
# Global model accuracy after round 7: 0.5322
# Round 8/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Communication overhead for round 8: 0.4676 MB
# Global model accuracy after round 8: 0.5463
# Round 9/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Communication overhead for round 9: 0.4676 MB
# Global model accuracy after round 9: 0.5601
# Round 10/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Communication overhead for round 10: 0.4676 MB
# Global model accuracy after round 10: 0.5732
# Round 11/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Communication overhead for round 11: 0.4676 MB
# Global model accuracy after round 11: 0.5832
# Round 12/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Communication overhead for round 12: 0.4676 MB
# Global model accuracy after round 12: 0.5929
# Round 13/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Communication overhead for round 13: 0.4676 MB
# Global model accuracy after round 13: 0.6004
# Round 14/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Communication overhead for round 14: 0.4676 MB
# Global model accuracy after round 14: 0.6106
# Round 15/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Communication overhead for round 15: 0.4676 MB
# Global model accuracy after round 15: 0.6173
# Round 16/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Communication overhead for round 16: 0.4676 MB
# Global model accuracy after round 16: 0.6268
# Round 17/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Communication overhead for round 17: 0.4676 MB
# Global model accuracy after round 17: 0.6283
# Round 18/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Communication overhead for round 18: 0.4676 MB
# Global model accuracy after round 18: 0.6385
# Round 19/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Communication overhead for round 19: 0.4676 MB
# Global model accuracy after round 19: 0.6419
# Round 20/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Communication overhead for round 20: 0.4676 MB
# Global model accuracy after round 20: 0.6483
# Round 21/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Communication overhead for round 21: 0.4676 MB
# Global model accuracy after round 21: 0.6497
# Round 22/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Communication overhead for round 22: 0.4676 MB
# Global model accuracy after round 22: 0.6545
# Round 23/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Communication overhead for round 23: 0.4676 MB
# Global model accuracy after round 23: 0.6578
# Round 24/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Communication overhead for round 24: 0.4676 MB
# Global model accuracy after round 24: 0.6582
# Round 25/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Communication overhead for round 25: 0.4676 MB
# Global model accuracy after round 25: 0.6651
# Round 26/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Communication overhead for round 26: 0.4676 MB
# Global model accuracy after round 26: 0.6654
# Round 27/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Communication overhead for round 27: 0.4676 MB
# Global model accuracy after round 27: 0.6678
# Round 28/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Communication overhead for round 28: 0.4676 MB
# Global model accuracy after round 28: 0.6650
# Round 29/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Communication overhead for round 29: 0.4676 MB
# Global model accuracy after round 29: 0.6690
# Round 30/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Communication overhead for round 30: 0.4676 MB
# Global model accuracy after round 30: 0.6705
# Final global model accuracy: 0.6705
# Total communication overhead: 14.0270 MB
# Convergence not achieved within 30 rounds.

# %% [markdown]
# **EXPERIMENT FIVE**

# %%
import tensorflow as tf
import numpy as np
import time
import matplotlib.pyplot as plt

# Load and preprocess the CIFAR-10 dataset
def load_and_preprocess_data():
    (x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

    # Preprocessing: normalize to [0,1]
    x_train = x_train.astype('float32') / 255.0
    x_test = x_test.astype('float32') / 255.0

    # One-hot encode labels
    y_train = tf.keras.utils.to_categorical(y_train, num_classes=10)
    y_test = tf.keras.utils.to_categorical(y_test, num_classes=10)

    return (x_train, y_train), (x_test, y_test)

# Define the global CNN model
def create_cnn_model():
    model = tf.keras.Sequential([
        tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(10, activation='softmax')
    ])
    return model

# Create federated data by splitting the dataset among clients
def create_federated_data(x, y, num_clients=10):
    client_data = []
    data_per_client = len(x) // num_clients
    for i in range(num_clients):
        client_x = x[i * data_per_client:(i + 1) * data_per_client]
        client_y = y[i * data_per_client:(i + 1) * data_per_client]
        client_data.append((client_x, client_y))
    return client_data

# Measure communication overhead
def measure_communication_overhead(weights):
    return sum([np.prod(w.shape) for w in weights]) * 4 / (1024 * 1024)  # in MB

# Federated learning parameters
num_clients = 50
num_rounds = 30
local_epochs = 3
accuracy_threshold = 0.70  # Define an accuracy threshold for convergence speed

# Load and preprocess data
(x_train, y_train), (x_test, y_test) = load_and_preprocess_data()

# Create federated data for each client
federated_train_data = create_federated_data(x_train, y_train, num_clients)

# Create global model
global_model = create_cnn_model()
global_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Initialize variables to measure communication overhead and convergence speed
total_communication_overhead = 0
convergence_round = None
start_time = time.time()

# Lists to store metrics for visualization
communication_overheads = []
accuracies = []
round_times = []

# Federated learning loop
for round_num in range(num_rounds):
    print(f"Round {round_num + 1}/{num_rounds}")

    local_weights = []
    round_start_time = time.time()

    # Train on each client
    for client_id in range(num_clients):
        print(f"Training on client {client_id + 1}")

        # Create local model and set global weights
        local_model = create_cnn_model()
        local_model.set_weights(global_model.get_weights())
        local_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

        # Get client data
        X, y = federated_train_data[client_id]

        # Train local model
        local_model.fit(X, y, epochs=local_epochs, batch_size=32, verbose=0)

        # Collect local model weights
        local_weights.append(local_model.get_weights())

    # Federated averaging: Aggregate local weights
    averaged_weights = [np.mean([local_weights[j][i] for j in range(num_clients)], axis=0)
                        for i in range(len(local_weights[0]))]

    # Measure communication overhead
    round_communication_overhead = measure_communication_overhead(averaged_weights)
    total_communication_overhead += round_communication_overhead
    communication_overheads.append(round_communication_overhead)
    print(f"Communication overhead for round {round_num + 1}: {round_communication_overhead:.4f} MB")

    # Update global model weights
    global_model.set_weights(averaged_weights)

    # Evaluate the global model
    loss, accuracy = global_model.evaluate(x_test, y_test, verbose=0)
    accuracies.append(accuracy)
    print(f"Global model accuracy after round {round_num + 1}: {accuracy:.4f}")

    # Check for convergence
    if convergence_round is None and accuracy >= accuracy_threshold:
        convergence_round = round_num + 1
        convergence_time = time.time() - start_time
        print(f"Convergence achieved at round {convergence_round} with accuracy {accuracy:.4f}")
        print(f"Convergence time: {convergence_time:.2f} seconds")

    # Record round time
    round_time = time.time() - round_start_time
    round_times.append(round_time)

# Evaluate the final global model
final_loss, final_accuracy = global_model.evaluate(x_test, y_test, verbose=0)
print(f"Final global model accuracy: {final_accuracy:.4f}")

# Print total communication overhead
print(f"Total communication overhead: {total_communication_overhead:.4f} MB")

# Print convergence information if not already printed
if convergence_round is None:
    convergence_time = time.time() - start_time
    print(f"Convergence not achieved within {num_rounds} rounds.")
else:
    print(f"Convergence achieved at round {convergence_round} with accuracy {final_accuracy:.4f}")
    print(f"Convergence time: {convergence_time:.2f} seconds")

# Visualization
rounds = list(range(1, num_rounds + 1))

plt.figure(figsize=(12, 6))

# Plot communication overhead
plt.subplot(1, 3, 1)
plt.plot(rounds, communication_overheads, marker='o')
plt.title('Communication Overhead per Round')
plt.xlabel('Round')
plt.ylabel('Communication Overhead (MB)')

# Plot accuracy
plt.subplot(1, 3, 2)
plt.plot(rounds, accuracies, marker='o')
plt.title('Global Model Accuracy per Round')
plt.xlabel('Round')
plt.ylabel('Accuracy')

# Plot round times
plt.subplot(1, 3, 3)
plt.plot(rounds, round_times, marker='o')
plt.title('Round Time')
plt.xlabel('Round')
plt.ylabel('Time (seconds)')

plt.tight_layout()
plt.show()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Round 1/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Communication overhead for round 1: 0.4676 MB
# Global model accuracy after round 1: 0.2473
# Round 2/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Communication overhead for round 2: 0.4676 MB
# Global model accuracy after round 2: 0.3713
# Round 3/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Communication overhead for round 3: 0.4676 MB
# Global model accuracy after round 3: 0.4320
# Round 4/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Communication overhead for round 4: 0.4676 MB
# Global model accuracy after round 4: 0.4676
# Round 5/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Communication overhead for round 5: 0.4676 MB
# Global model accuracy after round 5: 0.4872
# Round 6/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Communication overhead for round 6: 0.4676 MB
# Global model accuracy after round 6: 0.5099
# Round 7/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Communication overhead for round 7: 0.4676 MB
# Global model accuracy after round 7: 0.5245
# Round 8/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Communication overhead for round 8: 0.4676 MB
# Global model accuracy after round 8: 0.5363
# Round 9/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Communication overhead for round 9: 0.4676 MB
# Global model accuracy after round 9: 0.5499
# Round 10/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Communication overhead for round 10: 0.4676 MB
# Global model accuracy after round 10: 0.5600
# Round 11/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Communication overhead for round 11: 0.4676 MB
# Global model accuracy after round 11: 0.5733
# Round 12/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Communication overhead for round 12: 0.4676 MB
# Global model accuracy after round 12: 0.5840
# Round 13/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Communication overhead for round 13: 0.4676 MB
# Global model accuracy after round 13: 0.5924
# Round 14/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Communication overhead for round 14: 0.4676 MB
# Global model accuracy after round 14: 0.6014
# Round 15/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Communication overhead for round 15: 0.4676 MB
# Global model accuracy after round 15: 0.6093
# Round 16/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Communication overhead for round 16: 0.4676 MB
# Global model accuracy after round 16: 0.6171
# Round 17/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Communication overhead for round 17: 0.4676 MB
# Global model accuracy after round 17: 0.6259
# Round 18/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Communication overhead for round 18: 0.4676 MB
# Global model accuracy after round 18: 0.6299
# Round 19/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Communication overhead for round 19: 0.4676 MB
# Global model accuracy after round 19: 0.6354
# Round 20/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Communication overhead for round 20: 0.4676 MB
# Global model accuracy after round 20: 0.6422
# Round 21/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Communication overhead for round 21: 0.4676 MB
# Global model accuracy after round 21: 0.6481
# Round 22/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Communication overhead for round 22: 0.4676 MB
# Global model accuracy after round 22: 0.6504
# Round 23/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Communication overhead for round 23: 0.4676 MB
# Global model accuracy after round 23: 0.6523
# Round 24/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Communication overhead for round 24: 0.4676 MB
# Global model accuracy after round 24: 0.6581
# Round 25/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Communication overhead for round 25: 0.4676 MB
# Global model accuracy after round 25: 0.6608
# Round 26/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Communication overhead for round 26: 0.4676 MB
# Global model accuracy after round 26: 0.6660
# Round 27/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Communication overhead for round 27: 0.4676 MB
# Global model accuracy after round 27: 0.6680
# Round 28/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Communication overhead for round 28: 0.4676 MB
# Global model accuracy after round 28: 0.6697
# Round 29/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Communication overhead for round 29: 0.4676 MB
# Global model accuracy after round 29: 0.6723
# Round 30/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Communication overhead for round 30: 0.4676 MB
# Global model accuracy after round 30: 0.6741
# Final global model accuracy: 0.6741
# Total communication overhead: 14.0270 MB
# Convergence not achieved within 30 rounds.

# %% [markdown]
# **EXPERIMENT SIX**

# %%
import tensorflow as tf
import numpy as np
import time
import matplotlib.pyplot as plt

# Load and preprocess the CIFAR-10 dataset
def load_and_preprocess_data():
    (x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

    # Preprocessing: normalize to [0,1]
    x_train = x_train.astype('float32') / 255.0
    x_test = x_test.astype('float32') / 255.0

    # One-hot encode labels
    y_train = tf.keras.utils.to_categorical(y_train, num_classes=10)
    y_test = tf.keras.utils.to_categorical(y_test, num_classes=10)

    return (x_train, y_train), (x_test, y_test)

# Define the global CNN model
def create_cnn_model():
    model = tf.keras.Sequential([
        tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(10, activation='softmax')
    ])
    return model

# Create federated data by splitting the dataset among clients
def create_federated_data(x, y, num_clients=10):
    client_data = []
    data_per_client = len(x) // num_clients
    for i in range(num_clients):
        client_x = x[i * data_per_client:(i + 1) * data_per_client]
        client_y = y[i * data_per_client:(i + 1) * data_per_client]
        client_data.append((client_x, client_y))
    return client_data

# Measure communication overhead
def measure_communication_overhead(weights):
    return sum([np.prod(w.shape) for w in weights]) * 4 / (1024 * 1024)  # in MB

# Federated learning parameters
num_clients = 60
num_rounds = 30
local_epochs = 3
accuracy_threshold = 0.70  # Define an accuracy threshold for convergence speed

# Load and preprocess data
(x_train, y_train), (x_test, y_test) = load_and_preprocess_data()

# Create federated data for each client
federated_train_data = create_federated_data(x_train, y_train, num_clients)

# Create global model
global_model = create_cnn_model()
global_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Initialize variables to measure communication overhead and convergence speed
total_communication_overhead = 0
convergence_round = None
start_time = time.time()

# Lists to store metrics for visualization
communication_overheads = []
accuracies = []
round_times = []

# Federated learning loop
for round_num in range(num_rounds):
    print(f"Round {round_num + 1}/{num_rounds}")

    local_weights = []
    round_start_time = time.time()

    # Train on each client
    for client_id in range(num_clients):
        print(f"Training on client {client_id + 1}")

        # Create local model and set global weights
        local_model = create_cnn_model()
        local_model.set_weights(global_model.get_weights())
        local_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

        # Get client data
        X, y = federated_train_data[client_id]

        # Train local model
        local_model.fit(X, y, epochs=local_epochs, batch_size=32, verbose=0)

        # Collect local model weights
        local_weights.append(local_model.get_weights())

    # Federated averaging: Aggregate local weights
    averaged_weights = [np.mean([local_weights[j][i] for j in range(num_clients)], axis=0)
                        for i in range(len(local_weights[0]))]

    # Measure communication overhead
    round_communication_overhead = measure_communication_overhead(averaged_weights)
    total_communication_overhead += round_communication_overhead
    communication_overheads.append(round_communication_overhead)
    print(f"Communication overhead for round {round_num + 1}: {round_communication_overhead:.4f} MB")

    # Update global model weights
    global_model.set_weights(averaged_weights)

    # Evaluate the global model
    loss, accuracy = global_model.evaluate(x_test, y_test, verbose=0)
    accuracies.append(accuracy)
    print(f"Global model accuracy after round {round_num + 1}: {accuracy:.4f}")

    # Check for convergence
    if convergence_round is None and accuracy >= accuracy_threshold:
        convergence_round = round_num + 1
        convergence_time = time.time() - start_time
        print(f"Convergence achieved at round {convergence_round} with accuracy {accuracy:.4f}")
        print(f"Convergence time: {convergence_time:.2f} seconds")

    # Record round time
    round_time = time.time() - round_start_time
    round_times.append(round_time)

# Evaluate the final global model
final_loss, final_accuracy = global_model.evaluate(x_test, y_test, verbose=0)
print(f"Final global model accuracy: {final_accuracy:.4f}")

# Print total communication overhead
print(f"Total communication overhead: {total_communication_overhead:.4f} MB")

# Print convergence information if not already printed
if convergence_round is None:
    convergence_time = time.time() - start_time
    print(f"Convergence not achieved within {num_rounds} rounds.")
else:
    print(f"Convergence achieved at round {convergence_round} with accuracy {final_accuracy:.4f}")
    print(f"Convergence time: {convergence_time:.2f} seconds")

# Visualization
rounds = list(range(1, num_rounds + 1))

plt.figure(figsize=(12, 6))

# Plot communication overhead
plt.subplot(1, 3, 1)
plt.plot(rounds, communication_overheads, marker='o')
plt.title('Communication Overhead per Round')
plt.xlabel('Round')
plt.ylabel('Communication Overhead (MB)')

# Plot accuracy
plt.subplot(1, 3, 2)
plt.plot(rounds, accuracies, marker='o')
plt.title('Global Model Accuracy per Round')
plt.xlabel('Round')
plt.ylabel('Accuracy')

# Plot round times
plt.subplot(1, 3, 3)
plt.plot(rounds, round_times, marker='o')
plt.title('Round Time')
plt.xlabel('Round')
plt.ylabel('Time (seconds)')

plt.tight_layout()
plt.show()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Round 1/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Communication overhead for round 1: 0.4676 MB
# Global model accuracy after round 1: 0.2349
# Round 2/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Communication overhead for round 2: 0.4676 MB
# Global model accuracy after round 2: 0.3443
# Round 3/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Communication overhead for round 3: 0.4676 MB
# Global model accuracy after round 3: 0.3765
# Round 4/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Communication overhead for round 4: 0.4676 MB
# Global model accuracy after round 4: 0.4153
# Round 5/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Communication overhead for round 5: 0.4676 MB
# Global model accuracy after round 5: 0.4417
# Round 6/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Communication overhead for round 6: 0.4676 MB
# Global model accuracy after round 6: 0.4682
# Round 7/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Communication overhead for round 7: 0.4676 MB
# Global model accuracy after round 7: 0.4829
# Round 8/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Communication overhead for round 8: 0.4676 MB
# Global model accuracy after round 8: 0.4969
# Round 9/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Communication overhead for round 9: 0.4676 MB
# Global model accuracy after round 9: 0.5147
# Round 10/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Communication overhead for round 10: 0.4676 MB
# Global model accuracy after round 10: 0.5287
# Round 11/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Communication overhead for round 11: 0.4676 MB
# Global model accuracy after round 11: 0.5400
# Round 12/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Communication overhead for round 12: 0.4676 MB
# Global model accuracy after round 12: 0.5466
# Round 13/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Communication overhead for round 13: 0.4676 MB
# Global model accuracy after round 13: 0.5560
# Round 14/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Communication overhead for round 14: 0.4676 MB
# Global model accuracy after round 14: 0.5664
# Round 15/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Communication overhead for round 15: 0.4676 MB
# Global model accuracy after round 15: 0.5734
# Round 16/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Communication overhead for round 16: 0.4676 MB
# Global model accuracy after round 16: 0.5809
# Round 17/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Communication overhead for round 17: 0.4676 MB
# Global model accuracy after round 17: 0.5878
# Round 18/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Communication overhead for round 18: 0.4676 MB
# Global model accuracy after round 18: 0.5939
# Round 19/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Communication overhead for round 19: 0.4676 MB
# Global model accuracy after round 19: 0.5977
# Round 20/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Communication overhead for round 20: 0.4676 MB
# Global model accuracy after round 20: 0.6023
# Round 21/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Communication overhead for round 21: 0.4676 MB
# Global model accuracy after round 21: 0.6090
# Round 22/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Communication overhead for round 22: 0.4676 MB
# Global model accuracy after round 22: 0.6134
# Round 23/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Communication overhead for round 23: 0.4676 MB
# Global model accuracy after round 23: 0.6187
# Round 24/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Communication overhead for round 24: 0.4676 MB
# Global model accuracy after round 24: 0.6234
# Round 25/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Communication overhead for round 25: 0.4676 MB
# Global model accuracy after round 25: 0.6284
# Round 26/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Communication overhead for round 26: 0.4676 MB
# Global model accuracy after round 26: 0.6330
# Round 27/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Communication overhead for round 27: 0.4676 MB
# Global model accuracy after round 27: 0.6342
# Round 28/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Communication overhead for round 28: 0.4676 MB
# Global model accuracy after round 28: 0.6385
# Round 29/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Communication overhead for round 29: 0.4676 MB
# Global model accuracy after round 29: 0.6415
# Round 30/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Communication overhead for round 30: 0.4676 MB
# Global model accuracy after round 30: 0.6459
# Final global model accuracy: 0.6459
# Total communication overhead: 14.0270 MB
# Convergence not achieved within 30 rounds.

# %% [markdown]
# **EXPERIMENT SEVEN**

# %%
import tensorflow as tf
import numpy as np
import time
import matplotlib.pyplot as plt

# Load and preprocess the CIFAR-10 dataset
def load_and_preprocess_data():
    (x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

    # Preprocessing: normalize to [0,1]
    x_train = x_train.astype('float32') / 255.0
    x_test = x_test.astype('float32') / 255.0

    # One-hot encode labels
    y_train = tf.keras.utils.to_categorical(y_train, num_classes=10)
    y_test = tf.keras.utils.to_categorical(y_test, num_classes=10)

    return (x_train, y_train), (x_test, y_test)

# Define the global CNN model
def create_cnn_model():
    model = tf.keras.Sequential([
        tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(10, activation='softmax')
    ])
    return model

# Create federated data by splitting the dataset among clients
def create_federated_data(x, y, num_clients=10):
    client_data = []
    data_per_client = len(x) // num_clients
    for i in range(num_clients):
        client_x = x[i * data_per_client:(i + 1) * data_per_client]
        client_y = y[i * data_per_client:(i + 1) * data_per_client]
        client_data.append((client_x, client_y))
    return client_data

# Measure communication overhead
def measure_communication_overhead(weights):
    return sum([np.prod(w.shape) for w in weights]) * 4 / (1024 * 1024)  # in MB

# Federated learning parameters
num_clients = 70
num_rounds = 30
local_epochs = 3
accuracy_threshold = 0.70  # Define an accuracy threshold for convergence speed

# Load and preprocess data
(x_train, y_train), (x_test, y_test) = load_and_preprocess_data()

# Create federated data for each client
federated_train_data = create_federated_data(x_train, y_train, num_clients)

# Create global model
global_model = create_cnn_model()
global_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Initialize variables to measure communication overhead and convergence speed
total_communication_overhead = 0
convergence_round = None
start_time = time.time()

# Lists to store metrics for visualization
communication_overheads = []
accuracies = []
round_times = []

# Federated learning loop
for round_num in range(num_rounds):
    print(f"Round {round_num + 1}/{num_rounds}")

    local_weights = []
    round_start_time = time.time()

    # Train on each client
    for client_id in range(num_clients):
        print(f"Training on client {client_id + 1}")

        # Create local model and set global weights
        local_model = create_cnn_model()
        local_model.set_weights(global_model.get_weights())
        local_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

        # Get client data
        X, y = federated_train_data[client_id]

        # Train local model
        local_model.fit(X, y, epochs=local_epochs, batch_size=32, verbose=0)

        # Collect local model weights
        local_weights.append(local_model.get_weights())

    # Federated averaging: Aggregate local weights
    averaged_weights = [np.mean([local_weights[j][i] for j in range(num_clients)], axis=0)
                        for i in range(len(local_weights[0]))]

    # Measure communication overhead
    round_communication_overhead = measure_communication_overhead(averaged_weights)
    total_communication_overhead += round_communication_overhead
    communication_overheads.append(round_communication_overhead)
    print(f"Communication overhead for round {round_num + 1}: {round_communication_overhead:.4f} MB")

    # Update global model weights
    global_model.set_weights(averaged_weights)

    # Evaluate the global model
    loss, accuracy = global_model.evaluate(x_test, y_test, verbose=0)
    accuracies.append(accuracy)
    print(f"Global model accuracy after round {round_num + 1}: {accuracy:.4f}")

    # Check for convergence
    if convergence_round is None and accuracy >= accuracy_threshold:
        convergence_round = round_num + 1
        convergence_time = time.time() - start_time
        print(f"Convergence achieved at round {convergence_round} with accuracy {accuracy:.4f}")
        print(f"Convergence time: {convergence_time:.2f} seconds")

    # Record round time
    round_time = time.time() - round_start_time
    round_times.append(round_time)

# Evaluate the final global model
final_loss, final_accuracy = global_model.evaluate(x_test, y_test, verbose=0)
print(f"Final global model accuracy: {final_accuracy:.4f}")

# Print total communication overhead
print(f"Total communication overhead: {total_communication_overhead:.4f} MB")

# Print convergence information if not already printed
if convergence_round is None:
    convergence_time = time.time() - start_time
    print(f"Convergence not achieved within {num_rounds} rounds.")
else:
    print(f"Convergence achieved at round {convergence_round} with accuracy {final_accuracy:.4f}")
    print(f"Convergence time: {convergence_time:.2f} seconds")

# Visualization
rounds = list(range(1, num_rounds + 1))

plt.figure(figsize=(12, 6))

# Plot communication overhead
plt.subplot(1, 3, 1)
plt.plot(rounds, communication_overheads, marker='o')
plt.title('Communication Overhead per Round')
plt.xlabel('Round')
plt.ylabel('Communication Overhead (MB)')

# Plot accuracy
plt.subplot(1, 3, 2)
plt.plot(rounds, accuracies, marker='o')
plt.title('Global Model Accuracy per Round')
plt.xlabel('Round')
plt.ylabel('Accuracy')

# Plot round times
plt.subplot(1, 3, 3)
plt.plot(rounds, round_times, marker='o')
plt.title('Round Time')
plt.xlabel('Round')
plt.ylabel('Time (seconds)')

plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Round 1/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Communication overhead for round 1: 0.4676 MB
# Global model accuracy after round 1: 0.2672
# Round 2/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Communication overhead for round 2: 0.4676 MB
# Global model accuracy after round 2: 0.3525
# Round 3/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Communication overhead for round 3: 0.4676 MB
# Global model accuracy after round 3: 0.3925
# Round 4/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Communication overhead for round 4: 0.4676 MB
# Global model accuracy after round 4: 0.4214
# Round 5/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Communication overhead for round 5: 0.4676 MB
# Global model accuracy after round 5: 0.4446
# Round 6/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Communication overhead for round 6: 0.4676 MB
# Global model accuracy after round 6: 0.4692
# Round 7/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Communication overhead for round 7: 0.4676 MB
# Global model accuracy after round 7: 0.4867
# Round 8/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Communication overhead for round 8: 0.4676 MB
# Global model accuracy after round 8: 0.5044
# Round 9/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Communication overhead for round 9: 0.4676 MB
# Global model accuracy after round 9: 0.5172
# Round 10/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Communication overhead for round 10: 0.4676 MB
# Global model accuracy after round 10: 0.5285
# Round 11/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Communication overhead for round 11: 0.4676 MB
# Global model accuracy after round 11: 0.5378
# Round 12/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Communication overhead for round 12: 0.4676 MB
# Global model accuracy after round 12: 0.5491
# Round 13/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Communication overhead for round 13: 0.4676 MB
# Global model accuracy after round 13: 0.5584
# Round 14/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Communication overhead for round 14: 0.4676 MB
# Global model accuracy after round 14: 0.5657
# Round 15/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Communication overhead for round 15: 0.4676 MB
# Global model accuracy after round 15: 0.5735
# Round 16/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Communication overhead for round 16: 0.4676 MB
# Global model accuracy after round 16: 0.5821
# Round 17/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Communication overhead for round 17: 0.4676 MB
# Global model accuracy after round 17: 0.5881
# Round 18/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Communication overhead for round 18: 0.4676 MB
# Global model accuracy after round 18: 0.5926
# Round 19/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Communication overhead for round 19: 0.4676 MB
# Global model accuracy after round 19: 0.5965
# Round 20/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Communication overhead for round 20: 0.4676 MB
# Global model accuracy after round 20: 0.6030
# Round 21/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Communication overhead for round 21: 0.4676 MB
# Global model accuracy after round 21: 0.6099
# Round 22/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Communication overhead for round 22: 0.4676 MB
# Global model accuracy after round 22: 0.6151
# Round 23/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Communication overhead for round 23: 0.4676 MB
# Global model accuracy after round 23: 0.6210
# Round 24/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Communication overhead for round 24: 0.4676 MB
# Global model accuracy after round 24: 0.6251
# Round 25/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Communication overhead for round 25: 0.4676 MB
# Global model accuracy after round 25: 0.6287
# Round 26/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Communication overhead for round 26: 0.4676 MB
# Global model accuracy after round 26: 0.6340
# Round 27/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Communication overhead for round 27: 0.4676 MB
# Global model accuracy after round 27: 0.6375
# Round 28/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Communication overhead for round 28: 0.4676 MB
# Global model accuracy after round 28: 0.6402
# Round 29/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Communication overhead for round 29: 0.4676 MB
# Global model accuracy after round 29: 0.6420
# Round 30/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Communication overhead for round 30: 0.4676 MB
# Global model accuracy after round 30: 0.6469
# Final global model accuracy: 0.6469
# Total communication overhead: 14.0270 MB
# Convergence not achieved within 30 rounds.

# %% [markdown]
# **EXPERIMENT EIGHT**

# %%
import tensorflow as tf
import numpy as np
import time
import matplotlib.pyplot as plt

# Load and preprocess the CIFAR-10 dataset
def load_and_preprocess_data():
    (x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

    # Preprocessing: normalize to [0,1]
    x_train = x_train.astype('float32') / 255.0
    x_test = x_test.astype('float32') / 255.0

    # One-hot encode labels
    y_train = tf.keras.utils.to_categorical(y_train, num_classes=10)
    y_test = tf.keras.utils.to_categorical(y_test, num_classes=10)

    return (x_train, y_train), (x_test, y_test)

# Define the global CNN model
def create_cnn_model():
    model = tf.keras.Sequential([
        tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(10, activation='softmax')
    ])
    return model

# Create federated data by splitting the dataset among clients
def create_federated_data(x, y, num_clients=10):
    client_data = []
    data_per_client = len(x) // num_clients
    for i in range(num_clients):
        client_x = x[i * data_per_client:(i + 1) * data_per_client]
        client_y = y[i * data_per_client:(i + 1) * data_per_client]
        client_data.append((client_x, client_y))
    return client_data

# Measure communication overhead
def measure_communication_overhead(weights):
    return sum([np.prod(w.shape) for w in weights]) * 4 / (1024 * 1024)  # in MB

# Federated learning parameters
num_clients = 80
num_rounds = 30
local_epochs = 3
accuracy_threshold = 0.70  # Define an accuracy threshold for convergence speed

# Load and preprocess data
(x_train, y_train), (x_test, y_test) = load_and_preprocess_data()

# Create federated data for each client
federated_train_data = create_federated_data(x_train, y_train, num_clients)

# Create global model
global_model = create_cnn_model()
global_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Initialize variables to measure communication overhead and convergence speed
total_communication_overhead = 0
convergence_round = None
start_time = time.time()

# Lists to store metrics for visualization
communication_overheads = []
accuracies = []
round_times = []

# Federated learning loop
for round_num in range(num_rounds):
    print(f"Round {round_num + 1}/{num_rounds}")

    local_weights = []
    round_start_time = time.time()

    # Train on each client
    for client_id in range(num_clients):
        print(f"Training on client {client_id + 1}")

        # Create local model and set global weights
        local_model = create_cnn_model()
        local_model.set_weights(global_model.get_weights())
        local_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

        # Get client data
        X, y = federated_train_data[client_id]

        # Train local model
        local_model.fit(X, y, epochs=local_epochs, batch_size=32, verbose=0)

        # Collect local model weights
        local_weights.append(local_model.get_weights())

    # Federated averaging: Aggregate local weights
    averaged_weights = [np.mean([local_weights[j][i] for j in range(num_clients)], axis=0)
                        for i in range(len(local_weights[0]))]

    # Measure communication overhead
    round_communication_overhead = measure_communication_overhead(averaged_weights)
    total_communication_overhead += round_communication_overhead
    communication_overheads.append(round_communication_overhead)
    print(f"Communication overhead for round {round_num + 1}: {round_communication_overhead:.4f} MB")

    # Update global model weights
    global_model.set_weights(averaged_weights)

    # Evaluate the global model
    loss, accuracy = global_model.evaluate(x_test, y_test, verbose=0)
    accuracies.append(accuracy)
    print(f"Global model accuracy after round {round_num + 1}: {accuracy:.4f}")

    # Check for convergence
    if convergence_round is None and accuracy >= accuracy_threshold:
        convergence_round = round_num + 1
        convergence_time = time.time() - start_time
        print(f"Convergence achieved at round {convergence_round} with accuracy {accuracy:.4f}")
        print(f"Convergence time: {convergence_time:.2f} seconds")

    # Record round time
    round_time = time.time() - round_start_time
    round_times.append(round_time)

# Evaluate the final global model
final_loss, final_accuracy = global_model.evaluate(x_test, y_test, verbose=0)
print(f"Final global model accuracy: {final_accuracy:.4f}")

# Print total communication overhead
print(f"Total communication overhead: {total_communication_overhead:.4f} MB")

# Print convergence information if not already printed
if convergence_round is None:
    convergence_time = time.time() - start_time
    print(f"Convergence not achieved within {num_rounds} rounds.")
else:
    print(f"Convergence achieved at round {convergence_round} with accuracy {final_accuracy:.4f}")
    print(f"Convergence time: {convergence_time:.2f} seconds")

# Visualization
rounds = list(range(1, num_rounds + 1))

plt.figure(figsize=(12, 6))

# Plot communication overhead
plt.subplot(1, 3, 1)
plt.plot(rounds, communication_overheads, marker='o')
plt.title('Communication Overhead per Round')
plt.xlabel('Round')
plt.ylabel('Communication Overhead (MB)')

# Plot accuracy
plt.subplot(1, 3, 2)
plt.plot(rounds, accuracies, marker='o')
plt.title('Global Model Accuracy per Round')
plt.xlabel('Round')
plt.ylabel('Accuracy')

# Plot round times
plt.subplot(1, 3, 3)
plt.plot(rounds, round_times, marker='o')
plt.title('Round Time')
plt.xlabel('Round')
plt.ylabel('Time (seconds)')

plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Round 1/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Communication overhead for round 1: 0.4676 MB
# Global model accuracy after round 1: 0.2085
# Round 2/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Communication overhead for round 2: 0.4676 MB
# Global model accuracy after round 2: 0.3166
# Round 3/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Communication overhead for round 3: 0.4676 MB
# Global model accuracy after round 3: 0.3658
# Round 4/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Communication overhead for round 4: 0.4676 MB
# Global model accuracy after round 4: 0.4016
# Round 5/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Communication overhead for round 5: 0.4676 MB
# Global model accuracy after round 5: 0.4276
# Round 6/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Communication overhead for round 6: 0.4676 MB
# Global model accuracy after round 6: 0.4503
# Round 7/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Communication overhead for round 7: 0.4676 MB
# Global model accuracy after round 7: 0.4670
# Round 8/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Communication overhead for round 8: 0.4676 MB
# Global model accuracy after round 8: 0.4781
# Round 9/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Communication overhead for round 9: 0.4676 MB
# Global model accuracy after round 9: 0.4877
# Round 10/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Communication overhead for round 10: 0.4676 MB
# Global model accuracy after round 10: 0.4977
# Round 11/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Communication overhead for round 11: 0.4676 MB
# Global model accuracy after round 11: 0.5109
# Round 12/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Communication overhead for round 12: 0.4676 MB
# Global model accuracy after round 12: 0.5205
# Round 13/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Communication overhead for round 13: 0.4676 MB
# Global model accuracy after round 13: 0.5262
# Round 14/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Communication overhead for round 14: 0.4676 MB
# Global model accuracy after round 14: 0.5368
# Round 15/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Communication overhead for round 15: 0.4676 MB
# Global model accuracy after round 15: 0.5453
# Round 16/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Communication overhead for round 16: 0.4676 MB
# Global model accuracy after round 16: 0.5536
# Round 17/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Communication overhead for round 17: 0.4676 MB
# Global model accuracy after round 17: 0.5589
# Round 18/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Communication overhead for round 18: 0.4676 MB
# Global model accuracy after round 18: 0.5646
# Round 19/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Communication overhead for round 19: 0.4676 MB
# Global model accuracy after round 19: 0.5735
# Round 20/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Communication overhead for round 20: 0.4676 MB
# Global model accuracy after round 20: 0.5771
# Round 21/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Communication overhead for round 21: 0.4676 MB
# Global model accuracy after round 21: 0.5813
# Round 22/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Communication overhead for round 22: 0.4676 MB
# Global model accuracy after round 22: 0.5879
# Round 23/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Communication overhead for round 23: 0.4676 MB
# Global model accuracy after round 23: 0.5922
# Round 24/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Communication overhead for round 24: 0.4676 MB
# Global model accuracy after round 24: 0.5954
# Round 25/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Communication overhead for round 25: 0.4676 MB
# Global model accuracy after round 25: 0.6014
# Round 26/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Communication overhead for round 26: 0.4676 MB
# Global model accuracy after round 26: 0.6087
# Round 27/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Communication overhead for round 27: 0.4676 MB
# Global model accuracy after round 27: 0.6103
# Round 28/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Communication overhead for round 28: 0.4676 MB
# Global model accuracy after round 28: 0.6150
# Round 29/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Communication overhead for round 29: 0.4676 MB
# Global model accuracy after round 29: 0.6183
# Round 30/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Communication overhead for round 30: 0.4676 MB
# Global model accuracy after round 30: 0.6213
# Final global model accuracy: 0.6213
# Total communication overhead: 14.0270 MB
# Convergence not achieved within 30 rounds.

# %% [markdown]
# **EXPERIMENT NINE**

# %%
import tensorflow as tf
import numpy as np
import time
import matplotlib.pyplot as plt

# Load and preprocess the CIFAR-10 dataset
def load_and_preprocess_data():
    (x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

    # Preprocessing: normalize to [0,1]
    x_train = x_train.astype('float32') / 255.0
    x_test = x_test.astype('float32') / 255.0

    # One-hot encode labels
    y_train = tf.keras.utils.to_categorical(y_train, num_classes=10)
    y_test = tf.keras.utils.to_categorical(y_test, num_classes=10)

    return (x_train, y_train), (x_test, y_test)

# Define the global CNN model
def create_cnn_model():
    model = tf.keras.Sequential([
        tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(10, activation='softmax')
    ])
    return model

# Create federated data by splitting the dataset among clients
def create_federated_data(x, y, num_clients=10):
    client_data = []
    data_per_client = len(x) // num_clients
    for i in range(num_clients):
        client_x = x[i * data_per_client:(i + 1) * data_per_client]
        client_y = y[i * data_per_client:(i + 1) * data_per_client]
        client_data.append((client_x, client_y))
    return client_data

# Measure communication overhead
def measure_communication_overhead(weights):
    return sum([np.prod(w.shape) for w in weights]) * 4 / (1024 * 1024)  # in MB

# Federated learning parameters
num_clients = 90
num_rounds = 30
local_epochs = 3
accuracy_threshold = 0.70  # Define an accuracy threshold for convergence speed

# Load and preprocess data
(x_train, y_train), (x_test, y_test) = load_and_preprocess_data()

# Create federated data for each client
federated_train_data = create_federated_data(x_train, y_train, num_clients)

# Create global model
global_model = create_cnn_model()
global_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Initialize variables to measure communication overhead and convergence speed
total_communication_overhead = 0
convergence_round = None
start_time = time.time()

# Lists to store metrics for visualization
communication_overheads = []
accuracies = []
round_times = []

# Federated learning loop
for round_num in range(num_rounds):
    print(f"Round {round_num + 1}/{num_rounds}")

    local_weights = []
    round_start_time = time.time()

    # Train on each client
    for client_id in range(num_clients):
        print(f"Training on client {client_id + 1}")

        # Create local model and set global weights
        local_model = create_cnn_model()
        local_model.set_weights(global_model.get_weights())
        local_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

        # Get client data
        X, y = federated_train_data[client_id]

        # Train local model
        local_model.fit(X, y, epochs=local_epochs, batch_size=32, verbose=0)

        # Collect local model weights
        local_weights.append(local_model.get_weights())

    # Federated averaging: Aggregate local weights
    averaged_weights = [np.mean([local_weights[j][i] for j in range(num_clients)], axis=0)
                        for i in range(len(local_weights[0]))]

    # Measure communication overhead
    round_communication_overhead = measure_communication_overhead(averaged_weights)
    total_communication_overhead += round_communication_overhead
    communication_overheads.append(round_communication_overhead)
    print(f"Communication overhead for round {round_num + 1}: {round_communication_overhead:.4f} MB")

    # Update global model weights
    global_model.set_weights(averaged_weights)

    # Evaluate the global model
    loss, accuracy = global_model.evaluate(x_test, y_test, verbose=0)
    accuracies.append(accuracy)
    print(f"Global model accuracy after round {round_num + 1}: {accuracy:.4f}")

    # Check for convergence
    if convergence_round is None and accuracy >= accuracy_threshold:
        convergence_round = round_num + 1
        convergence_time = time.time() - start_time
        print(f"Convergence achieved at round {convergence_round} with accuracy {accuracy:.4f}")
        print(f"Convergence time: {convergence_time:.2f} seconds")

    # Record round time
    round_time = time.time() - round_start_time
    round_times.append(round_time)

# Evaluate the final global model
final_loss, final_accuracy = global_model.evaluate(x_test, y_test, verbose=0)
print(f"Final global model accuracy: {final_accuracy:.4f}")

# Print total communication overhead
print(f"Total communication overhead: {total_communication_overhead:.4f} MB")

# Print convergence information if not already printed
if convergence_round is None:
    convergence_time = time.time() - start_time
    print(f"Convergence not achieved within {num_rounds} rounds.")
else:
    print(f"Convergence achieved at round {convergence_round} with accuracy {final_accuracy:.4f}")
    print(f"Convergence time: {convergence_time:.2f} seconds")

# Visualization
rounds = list(range(1, num_rounds + 1))

plt.figure(figsize=(12, 6))

# Plot communication overhead
plt.subplot(1, 3, 1)
plt.plot(rounds, communication_overheads, marker='o')
plt.title('Communication Overhead per Round')
plt.xlabel('Round')
plt.ylabel('Communication Overhead (MB)')

# Plot accuracy
plt.subplot(1, 3, 2)
plt.plot(rounds, accuracies, marker='o')
plt.title('Global Model Accuracy per Round')
plt.xlabel('Round')
plt.ylabel('Accuracy')

# Plot round times
plt.subplot(1, 3, 3)
plt.plot(rounds, round_times, marker='o')
plt.title('Round Time')
plt.xlabel('Round')
plt.ylabel('Time (seconds)')

plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Round 1/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Communication overhead for round 1: 0.4676 MB
# Global model accuracy after round 1: 0.2079
# Round 2/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Communication overhead for round 2: 0.4676 MB
# Global model accuracy after round 2: 0.2765
# Round 3/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Communication overhead for round 3: 0.4676 MB
# Global model accuracy after round 3: 0.3550
# Round 4/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Communication overhead for round 4: 0.4676 MB
# Global model accuracy after round 4: 0.3808
# Round 5/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Communication overhead for round 5: 0.4676 MB
# Global model accuracy after round 5: 0.4062
# Round 6/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Communication overhead for round 6: 0.4676 MB
# Global model accuracy after round 6: 0.4243
# Round 7/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Communication overhead for round 7: 0.4676 MB
# Global model accuracy after round 7: 0.4417
# Round 8/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Communication overhead for round 8: 0.4676 MB
# Global model accuracy after round 8: 0.4576
# Round 9/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Communication overhead for round 9: 0.4676 MB
# Global model accuracy after round 9: 0.4679
# Round 10/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Communication overhead for round 10: 0.4676 MB
# Global model accuracy after round 10: 0.4776
# Round 11/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Communication overhead for round 11: 0.4676 MB
# Global model accuracy after round 11: 0.4910
# Round 12/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Communication overhead for round 12: 0.4676 MB
# Global model accuracy after round 12: 0.4997
# Round 13/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Communication overhead for round 13: 0.4676 MB
# Global model accuracy after round 13: 0.5126
# Round 14/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Communication overhead for round 14: 0.4676 MB
# Global model accuracy after round 14: 0.5211
# Round 15/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Communication overhead for round 15: 0.4676 MB
# Global model accuracy after round 15: 0.5266
# Round 16/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Communication overhead for round 16: 0.4676 MB
# Global model accuracy after round 16: 0.5359
# Round 17/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Communication overhead for round 17: 0.4676 MB
# Global model accuracy after round 17: 0.5414
# Round 18/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Communication overhead for round 18: 0.4676 MB
# Global model accuracy after round 18: 0.5481
# Round 19/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Communication overhead for round 19: 0.4676 MB
# Global model accuracy after round 19: 0.5535
# Round 20/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Communication overhead for round 20: 0.4676 MB
# Global model accuracy after round 20: 0.5581
# Round 21/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Communication overhead for round 21: 0.4676 MB
# Global model accuracy after round 21: 0.5644
# Round 22/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Communication overhead for round 22: 0.4676 MB
# Global model accuracy after round 22: 0.5684
# Round 23/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Communication overhead for round 23: 0.4676 MB
# Global model accuracy after round 23: 0.5738
# Round 24/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Communication overhead for round 24: 0.4676 MB
# Global model accuracy after round 24: 0.5760
# Round 25/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Communication overhead for round 25: 0.4676 MB
# Global model accuracy after round 25: 0.5797
# Round 26/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Communication overhead for round 26: 0.4676 MB
# Global model accuracy after round 26: 0.5840
# Round 27/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Communication overhead for round 27: 0.4676 MB
# Global model accuracy after round 27: 0.5883
# Round 28/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Communication overhead for round 28: 0.4676 MB
# Global model accuracy after round 28: 0.5888
# Round 29/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Communication overhead for round 29: 0.4676 MB
# Global model accuracy after round 29: 0.5941
# Round 30/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Communication overhead for round 30: 0.4676 MB
# Global model accuracy after round 30: 0.5974
# Final global model accuracy: 0.5974
# Total communication overhead: 14.0270 MB
# Convergence not achieved within 30 rounds.

# %% [markdown]
# **EXPERIMENT TEN**

# %%
import tensorflow as tf
import numpy as np
import time
import matplotlib.pyplot as plt

# Load and preprocess the CIFAR-10 dataset
def load_and_preprocess_data():
    (x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

    # Preprocessing: normalize to [0,1]
    x_train = x_train.astype('float32') / 255.0
    x_test = x_test.astype('float32') / 255.0

    # One-hot encode labels
    y_train = tf.keras.utils.to_categorical(y_train, num_classes=10)
    y_test = tf.keras.utils.to_categorical(y_test, num_classes=10)

    return (x_train, y_train), (x_test, y_test)

# Define the global CNN model
def create_cnn_model():
    model = tf.keras.Sequential([
        tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(10, activation='softmax')
    ])
    return model

# Create federated data by splitting the dataset among clients
def create_federated_data(x, y, num_clients=10):
    client_data = []
    data_per_client = len(x) // num_clients
    for i in range(num_clients):
        client_x = x[i * data_per_client:(i + 1) * data_per_client]
        client_y = y[i * data_per_client:(i + 1) * data_per_client]
        client_data.append((client_x, client_y))
    return client_data

# Measure communication overhead
def measure_communication_overhead(weights):
    return sum([np.prod(w.shape) for w in weights]) * 4 / (1024 * 1024)  # in MB

# Federated learning parameters
num_clients = 100
num_rounds = 30
local_epochs = 3
accuracy_threshold = 0.70  # Define an accuracy threshold for convergence speed

# Load and preprocess data
(x_train, y_train), (x_test, y_test) = load_and_preprocess_data()

# Create federated data for each client
federated_train_data = create_federated_data(x_train, y_train, num_clients)

# Create global model
global_model = create_cnn_model()
global_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Initialize variables to measure communication overhead and convergence speed
total_communication_overhead = 0
convergence_round = None
start_time = time.time()

# Lists to store metrics for visualization
communication_overheads = []
accuracies = []
round_times = []

# Federated learning loop
for round_num in range(num_rounds):
    print(f"Round {round_num + 1}/{num_rounds}")

    local_weights = []
    round_start_time = time.time()

    # Train on each client
    for client_id in range(num_clients):
        print(f"Training on client {client_id + 1}")

        # Create local model and set global weights
        local_model = create_cnn_model()
        local_model.set_weights(global_model.get_weights())
        local_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

        # Get client data
        X, y = federated_train_data[client_id]

        # Train local model
        local_model.fit(X, y, epochs=local_epochs, batch_size=32, verbose=0)

        # Collect local model weights
        local_weights.append(local_model.get_weights())

    # Federated averaging: Aggregate local weights
    averaged_weights = [np.mean([local_weights[j][i] for j in range(num_clients)], axis=0)
                        for i in range(len(local_weights[0]))]

    # Measure communication overhead
    round_communication_overhead = measure_communication_overhead(averaged_weights)
    total_communication_overhead += round_communication_overhead
    communication_overheads.append(round_communication_overhead)
    print(f"Communication overhead for round {round_num + 1}: {round_communication_overhead:.4f} MB")

    # Update global model weights
    global_model.set_weights(averaged_weights)

    # Evaluate the global model
    loss, accuracy = global_model.evaluate(x_test, y_test, verbose=0)
    accuracies.append(accuracy)
    print(f"Global model accuracy after round {round_num + 1}: {accuracy:.4f}")

    # Check for convergence
    if convergence_round is None and accuracy >= accuracy_threshold:
        convergence_round = round_num + 1
        convergence_time = time.time() - start_time
        print(f"Convergence achieved at round {convergence_round} with accuracy {accuracy:.4f}")
        print(f"Convergence time: {convergence_time:.2f} seconds")

    # Record round time
    round_time = time.time() - round_start_time
    round_times.append(round_time)

# Evaluate the final global model
final_loss, final_accuracy = global_model.evaluate(x_test, y_test, verbose=0)
print(f"Final global model accuracy: {final_accuracy:.4f}")

# Print total communication overhead
print(f"Total communication overhead: {total_communication_overhead:.4f} MB")

# Print convergence information if not already printed
if convergence_round is None:
    convergence_time = time.time() - start_time
    print(f"Convergence not achieved within {num_rounds} rounds.")
else:
    print(f"Convergence achieved at round {convergence_round} with accuracy {final_accuracy:.4f}")
    print(f"Convergence time: {convergence_time:.2f} seconds")

# Visualization
rounds = list(range(1, num_rounds + 1))

plt.figure(figsize=(12, 6))

# Plot communication overhead
plt.subplot(1, 3, 1)
plt.plot(rounds, communication_overheads, marker='o')
plt.title('Communication Overhead per Round')
plt.xlabel('Round')
plt.ylabel('Communication Overhead (MB)')

# Plot accuracy
plt.subplot(1, 3, 2)
plt.plot(rounds, accuracies, marker='o')
plt.title('Global Model Accuracy per Round')
plt.xlabel('Round')
plt.ylabel('Accuracy')

# Plot round times
plt.subplot(1, 3, 3)
plt.plot(rounds, round_times, marker='o')
plt.title('Round Time')
plt.xlabel('Round')
plt.ylabel('Time (seconds)')

plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Round 1/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 1: 0.4676 MB
# Global model accuracy after round 1: 0.1987
# Round 2/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 2: 0.4676 MB
# Global model accuracy after round 2: 0.2845
# Round 3/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 3: 0.4676 MB
# Global model accuracy after round 3: 0.3512
# Round 4/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 4: 0.4676 MB
# Global model accuracy after round 4: 0.3923
# Round 5/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 5: 0.4676 MB
# Global model accuracy after round 5: 0.4169
# Round 6/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 6: 0.4676 MB
# Global model accuracy after round 6: 0.4396
# Round 7/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 7: 0.4676 MB
# Global model accuracy after round 7: 0.4566
# Round 8/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 8: 0.4676 MB
# Global model accuracy after round 8: 0.4695
# Round 9/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 9: 0.4676 MB
# Global model accuracy after round 9: 0.4815
# Round 10/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 10: 0.4676 MB
# Global model accuracy after round 10: 0.4911
# Round 11/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 11: 0.4676 MB
# Global model accuracy after round 11: 0.5015
# Round 12/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 12: 0.4676 MB
# Global model accuracy after round 12: 0.5063
# Round 13/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 13: 0.4676 MB
# Global model accuracy after round 13: 0.5141
# Round 14/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 14: 0.4676 MB
# Global model accuracy after round 14: 0.5218
# Round 15/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 15: 0.4676 MB
# Global model accuracy after round 15: 0.5286
# Round 16/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 16: 0.4676 MB
# Global model accuracy after round 16: 0.5359
# Round 17/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 17: 0.4676 MB
# Global model accuracy after round 17: 0.5420
# Round 18/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 18: 0.4676 MB
# Global model accuracy after round 18: 0.5473
# Round 19/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 19: 0.4676 MB
# Global model accuracy after round 19: 0.5528
# Round 20/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 20: 0.4676 MB
# Global model accuracy after round 20: 0.5567
# Round 21/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# ...
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 24: 0.4676 MB
# Global model accuracy after round 24: 0.5744
# Round 25/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 25: 0.4676 MB
# Global model accuracy after round 25: 0.5757
# Round 26/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 26: 0.4676 MB
# Global model accuracy after round 26: 0.5815
# Round 27/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 27: 0.4676 MB
# Global model accuracy after round 27: 0.5858
# Round 28/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 28: 0.4676 MB
# Global model accuracy after round 28: 0.5892
# Round 29/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 29: 0.4676 MB
# Global model accuracy after round 29: 0.5945
# Round 30/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 30: 0.4676 MB
# Global model accuracy after round 30: 0.5976
# Final global model accuracy: 0.5976
# Total communication overhead: 14.0270 MB
# Convergence not achieved within 30 rounds.

# %% [markdown]
# **CENTRALIZED EXPERIMENT**

# %%
import tensorflow as tf
import numpy as np
import time
import matplotlib.pyplot as plt

# Load and preprocess the CIFAR-10 dataset
def load_and_preprocess_data():
    (x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

    # Preprocessing: normalize to [0,1]
    x_train = x_train.astype('float32') / 255.0
    x_test = x_test.astype('float32') / 255.0

    # One-hot encode labels
    y_train = tf.keras.utils.to_categorical(y_train, num_classes=10)
    y_test = tf.keras.utils.to_categorical(y_test, num_classes=10)

    return (x_train, y_train), (x_test, y_test)

# Define the global CNN model
def create_cnn_model():
    model = tf.keras.Sequential([
        tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(10, activation='softmax')
    ])
    return model

# Load and preprocess data
(x_train, y_train), (x_test, y_test) = load_and_preprocess_data()

# Create and compile the model
model = create_cnn_model()
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
start_time = time.time()
history = model.fit(x_train, y_train, epochs=30, batch_size=32, validation_data=(x_test, y_test), verbose=1)
training_time = time.time() - start_time

# Evaluate the model
final_loss, final_accuracy = model.evaluate(x_test, y_test, verbose=0)
print(f"Final model accuracy: {final_accuracy:.4f}")
print(f"Training time: {training_time:.2f} seconds")

# Visualization
plt.figure(figsize=(12, 6))

# Plot accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='test')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 29s 17ms/step - accuracy: 0.3502 - loss: 1.7511 - val_accuracy: 0.5386 - val_loss: 1.2939
# Epoch 2/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 25s 16ms/step - accuracy: 0.5877 - loss: 1.1572 - val_accuracy: 0.6301 - val_loss: 1.0475
# Epoch 3/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 24s 16ms/step - accuracy: 0.6516 - loss: 0.9944 - val_accuracy: 0.6630 - val_loss: 0.9644
# Epoch 4/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 25s 16ms/step - accuracy: 0.6917 - loss: 0.8806 - val_accuracy: 0.6903 - val_loss: 0.8833
# Epoch 5/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 24s 16ms/step - accuracy: 0.7196 - loss: 0.8015 - val_accuracy: 0.7034 - val_loss: 0.8534
# Epoch 6/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 25s 16ms/step - accuracy: 0.7373 - loss: 0.7444 - val_accuracy: 0.7023 - val_loss: 0.8888
# Epoch 7/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 25s 16ms/step - accuracy: 0.7646 - loss: 0.6743 - val_accuracy: 0.7026 - val_loss: 0.8583
# Epoch 8/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 25s 16ms/step - accuracy: 0.7737 - loss: 0.6390 - val_accuracy: 0.7147 - val_loss: 0.8484
# Epoch 9/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 25s 16ms/step - accuracy: 0.7887 - loss: 0.6001 - val_accuracy: 0.7116 - val_loss: 0.8740
# Epoch 10/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 25s 16ms/step - accuracy: 0.8077 - loss: 0.5478 - val_accuracy: 0.7133 - val_loss: 0.8500
# Epoch 11/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 25s 16ms/step - accuracy: 0.8202 - loss: 0.5080 - val_accuracy: 0.7122 - val_loss: 0.9094
# Epoch 12/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 24s 16ms/step - accuracy: 0.8285 - loss: 0.4826 - val_accuracy: 0.7179 - val_loss: 0.8981
# Epoch 13/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 25s 16ms/step - accuracy: 0.8484 - loss: 0.4308 - val_accuracy: 0.7192 - val_loss: 0.9215
# Epoch 14/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 25s 16ms/step - accuracy: 0.8561 - loss: 0.4090 - val_accuracy: 0.7058 - val_loss: 1.0097
# Epoch 15/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 25s 16ms/step - accuracy: 0.8642 - loss: 0.3795 - val_accuracy: 0.7177 - val_loss: 0.9787
# Epoch 16/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 25s 16ms/step - accuracy: 0.8791 - loss: 0.3466 - val_accuracy: 0.7140 - val_loss: 1.0552
# Epoch 17/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 24s 16ms/step - accuracy: 0.8848 - loss: 0.3260 - val_accuracy: 0.7089 - val_loss: 1.0852
# Epoch 18/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 41s 16ms/step - accuracy: 0.8910 - loss: 0.3030 - val_accuracy: 0.7082 - val_loss: 1.1419
# Epoch 19/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 24s 16ms/step - accuracy: 0.8993 - loss: 0.2778 - val_accuracy: 0.7118 - val_loss: 1.1260
# Epoch 20/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 24s 16ms/step - accuracy: 0.9068 - loss: 0.2605 - val_accuracy: 0.7061 - val_loss: 1.2052
# Epoch 21/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 24s 15ms/step - accuracy: 0.9131 - loss: 0.2420 - val_accuracy: 0.7076 - val_loss: 1.2611
# Epoch 22/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 24s 15ms/step - accuracy: 0.9188 - loss: 0.2286 - val_accuracy: 0.7051 - val_loss: 1.3370
# Epoch 23/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 24s 15ms/step - accuracy: 0.9235 - loss: 0.2148 - val_accuracy: 0.6986 - val_loss: 1.3818
# Epoch 24/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 24s 15ms/step - accuracy: 0.9287 - loss: 0.2022 - val_accuracy: 0.6919 - val_loss: 1.5287
# Epoch 25/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 24s 15ms/step - accuracy: 0.9307 - loss: 0.1931 - val_accuracy: 0.6911 - val_loss: 1.5487
# Epoch 26/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 24s 16ms/step - accuracy: 0.9331 - loss: 0.1817 - val_accuracy: 0.6876 - val_loss: 1.5965
# Epoch 27/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 24s 15ms/step - accuracy: 0.9389 - loss: 0.1677 - val_accuracy: 0.6990 - val_loss: 1.6103
# Epoch 28/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 24s 15ms/step - accuracy: 0.9435 - loss: 0.1573 - val_accuracy: 0.6948 - val_loss: 1.6855
# Epoch 29/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 25s 16ms/step - accuracy: 0.9456 - loss: 0.1514 - val_accuracy: 0.6934 - val_loss: 1.7791
# Epoch 30/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 24s 16ms/step - accuracy: 0.9488 - loss: 0.1483 - val_accuracy: 0.6977 - val_loss: 1.8315
# Final model accuracy: 0.6977
# Training time: 757.70 seconds
