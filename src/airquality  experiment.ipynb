# %%
#mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Importing  necessary libraries
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import time

# Loading and preprocessing the Air Quality dataset
def load_and_preprocess_data(filepath):
    # Load the dataset
    df = pd.read_excel(filepath)

    # Displaying the first few rows of the dataset
    print("First few rows of the dataset:")
    print(df.head())

    # Displaying the shape of the dataset
    print("\nShape of the dataset:")
    print(df.shape)

    # Displaying the column names
    print("\nColumn names:")
    print(df.columns)

    # Converting Time column to string
    df['Time'] = df['Time'].astype(str)

    # Combining Date and Time columns into a single datetime column
    df['Date_Time'] = pd.to_datetime(df['Date'].astype(str) + ' ' + df['Time'])
    df.drop(['Date', 'Time'], axis=1, inplace=True)

    # Replacing comma with dot for decimal conversion and converting to numeric
    for col in df.columns:
        if df[col].dtype == 'object':
            df[col] = df[col].str.replace(',', '.').astype(float)

    # Interpolate missing values
    df = df.interpolate(method='linear')

    # Dropping any remaining rows with missing values
    df = df.dropna()

    # Displaying the first few rows of the preprocessed data
    print("\nFirst few rows of the preprocessed data:")
    print(df.head())

    # Displaying the shape of the preprocessed data
    print("\nShape of the preprocessed data:")
    print(df.shape)

    # Checking for null values in the preprocessed data
    print("\nNull values in the preprocessed data:")
    print(df.isnull().sum())

    # Converting to numpy array
    data = df.drop(['Date_Time'], axis=1).values

    # Normalizing the data
    scaler = StandardScaler()
    data_scaled = scaler.fit_transform(data)

    # Displaying the shape of the scaled data
    print("\nShape of the scaled data:")
    print(data_scaled.shape)

    # Splitting the data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(data_scaled, data_scaled, test_size=0.2, random_state=42)

    return (X_train, y_train), (X_test, y_test), y_train.shape[1]

# File path to the dataset
file_path = '/content/drive/MyDrive/AirQualityUCI.xlsx'

# Load and preprocess data
(x_train, y_train), (x_test, y_test), num_classes = load_and_preprocess_data(file_path)

# Display the shapes of the training and testing sets
print("\nShape of the training data (X_train, y_train):")
print(x_train.shape, y_train.shape)
print("Shape of the testing data (X_test, y_test):")
print(x_test.shape, y_test.shape)
# Out:
# First few rows of the dataset:
#         Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  \
# 0 2004-03-10  18:00:00     2.6      1360.00       150  11.881723
# 1 2004-03-10  19:00:00     2.0      1292.25       112   9.397165
# 2 2004-03-10  20:00:00     2.2      1402.00        88   8.997817
# 3 2004-03-10  21:00:00     2.2      1375.50        80   9.228796
# 4 2004-03-10  22:00:00     1.6      1272.25        51   6.518224
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0        1045.50    166.0       1056.25    113.0       1692.00      1267.50
# 1         954.75    103.0       1173.75     92.0       1558.75       972.25
# 2         939.25    131.0       1140.00    114.0       1554.50      1074.00
# 3         948.25    172.0       1092.00    122.0       1583.75      1203.25
# 4         835.50    131.0       1205.00    116.0       1490.00      1110.00
#
#        T         RH        AH
# 0  13.60  48.875001  0.757754
# 1  13.30  47.700000  0.725487
# 2  11.90  53.975000  0.750239
# 3  11.00  60.000000  0.786713
# 4  11.15  59.575001  0.788794
#
# Shape of the dataset:
# (9357, 15)
#
# Column names:
# Index(['Date', 'Time', 'CO(GT)', 'PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)',
#        'PT08.S2(NMHC)', 'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)',
#        'PT08.S5(O3)', 'T', 'RH', 'AH'],
#       dtype='object')
#
# First few rows of the preprocessed data:
#    CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  \
# 0     2.6      1360.00       150  11.881723        1045.50    166.0
# 1     2.0      1292.25       112   9.397165         954.75    103.0
# 2     2.2      1402.00        88   8.997817         939.25    131.0
# 3     2.2      1375.50        80   9.228796         948.25    172.0
# 4     1.6      1272.25        51   6.518224         835.50    131.0
#
#    PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)      T         RH  \
# 0       1056.25    113.0       1692.00      1267.50  13.60  48.875001
# 1       1173.75     92.0       1558.75       972.25  13.30  47.700000
# 2       1140.00    114.0       1554.50      1074.00  11.90  53.975000
# 3       1092.00    122.0       1583.75      1203.25  11.00  60.000000
# 4       1205.00    116.0       1490.00      1110.00  11.15  59.575001
#
#          AH           Date_Time
# 0  0.757754 2004-03-10 18:00:00
# 1  0.725487 2004-03-10 19:00:00
# 2  0.750239 2004-03-10 20:00:00
# 3  0.786713 2004-03-10 21:00:00
# 4  0.788794 2004-03-10 22:00:00
#
# Shape of the preprocessed data:
# (9357, 14)
#
# Null values in the preprocessed data:
# CO(GT)           0
# PT08.S1(CO)      0
# NMHC(GT)         0
# C6H6(GT)         0
# PT08.S2(NMHC)    0
# NOx(GT)          0
# PT08.S3(NOx)     0
# NO2(GT)          0
# PT08.S4(NO2)     0
# PT08.S5(O3)      0
# T                0
# RH               0
# AH               0
# Round 22/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Communication overhead for round 22: 0.2095 MB
# Global model accuracy after round 22: 0.2591
# Round 23/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Communication overhead for round 23: 0.2095 MB
# Global model accuracy after round 23: 0.2596
# Round 24/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Communication overhead for round 24: 0.2095 MB
# Global model accuracy after round 24: 0.2580
# Round 25/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Communication overhead for round 25: 0.2095 MB
# Global model accuracy after round 25: 0.2580
# Round 26/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Communication overhead for round 26: 0.2095 MB
# Global model accuracy after round 26: 0.2591
# Round 27/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Communication overhead for round 27: 0.2095 MB
# Global model accuracy after round 27: 0.2575
# Round 28/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Communication overhead for round 28: 0.2095 MB
# Global model accuracy after round 28: 0.2601
# Round 29/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Communication overhead for round 29: 0.2095 MB
# Global model accuracy after round 29: 0.2591
# Round 30/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Communication overhead for round 30: 0.2095 MB
# Global model accuracy after round 30: 0.2591
# Final global model accuracy: 0.2591
# Total communication overhead: 6.2857 MB
# Convergence not achieved within 30 rounds.

# %% [markdown]
# **EXPERIMENT TEN**

# %%
# Define the global RNN model
def create_rnn_model(input_shape, num_classes):
    model = tf.keras.Sequential([
        tf.keras.layers.LSTM(64, input_shape=input_shape, return_sequences=True),
        tf.keras.layers.LSTM(64),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(num_classes, activation='softmax')
    ])
    return model

# Create federated data by splitting the dataset among clients
def create_federated_data(x, y, num_clients=100):
    client_data = []
    data_per_client = len(x) // num_clients
    for i in range(num_clients):
        client_x = x[i * data_per_client:(i + 1) * data_per_client]
        client_y = y[i * data_per_client:(i + 1) * data_per_client]
        client_data.append((client_x, client_y))
    return client_data

# Create federated data for each client
num_clients = 100
federated_train_data = create_federated_data(x_train, y_train, num_clients=num_clients)

# Measure communication overhead
def measure_communication_overhead(weights):
    return sum([np.prod(w.shape) for w in weights]) * 4 / (1024 * 1024)  # in MB

# Federated learning parameters
num_rounds = 30
local_epochs = 3
accuracy_threshold = 0.70  # Define an accuracy threshold for convergence speed

# Create global model
input_shape = (x_train.shape[1], 1)  # Adjust input shape for LSTM
global_model = create_rnn_model(input_shape, num_classes)
global_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Initialize variables to measure communication overhead and convergence speed
total_communication_overhead = 0
convergence_round = None
start_time = time.time()

# Lists to store metrics for visualization
communication_overheads = []
accuracies = []
round_times = []

# Federated learning loop
for round_num in range(num_rounds):
    print(f"Round {round_num + 1}/{num_rounds}")

    local_weights = []
    round_start_time = time.time()

    # Train on each client
    for client_id in range(num_clients):
        print(f"Training on client {client_id + 1}")

        # Create local model and set global weights
        local_model = create_rnn_model(input_shape, num_classes)
        local_model.set_weights(global_model.get_weights())
        local_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

        # Get client data
        X, y = federated_train_data[client_id]

        # Reshape data for LSTM
        X = X.reshape((X.shape[0], X.shape[1], 1))

        # Train local model
        local_model.fit(X, y, epochs=local_epochs, batch_size=32, verbose=0)

        # Collect local model weights
        local_weights.append(local_model.get_weights())

    # Federated averaging: Aggregate local weights
    averaged_weights = [np.mean([local_weights[j][i] for j in range(num_clients)], axis=0)
                        for i in range(len(local_weights[0]))]

    # Measure communication overhead
    round_communication_overhead = measure_communication_overhead(averaged_weights)
    total_communication_overhead += round_communication_overhead
    communication_overheads.append(round_communication_overhead)
    print(f"Communication overhead for round {round_num + 1}: {round_communication_overhead:.4f} MB")

    # Update global model weights
    global_model.set_weights(averaged_weights)

    # Evaluate the global model
    x_test_reshaped = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))
    loss, accuracy = global_model.evaluate(x_test_reshaped, y_test, verbose=0)
    accuracies.append(accuracy)
    print(f"Global model accuracy after round {round_num + 1}: {accuracy:.4f}")

    # Check for convergence
    if convergence_round is None and accuracy >= accuracy_threshold:
        convergence_round = round_num + 1
        convergence_time = time.time() - start_time
        print(f"Convergence achieved at round {convergence_round} with accuracy {accuracy:.4f}")
        print(f"Convergence time: {convergence_time:.2f} seconds")

    # Record round time
    round_time = time.time() - round_start_time
    round_times.append(round_time)

# Evaluate the final global model
final_loss, final_accuracy = global_model.evaluate(x_test_reshaped, y_test, verbose=0)
print(f"Final global model accuracy: {final_accuracy:.4f}")

# Print total communication overhead
print(f"Total communication overhead: {total_communication_overhead:.4f} MB")

# Print convergence information if not already printed
if convergence_round is None:
    convergence_time = time.time() - start_time
    print(f"Convergence not achieved within {num_rounds} rounds.")
else:
    print(f"Convergence achieved at round {convergence_round} with accuracy {final_accuracy:.4f}")
    print(f"Convergence time: {convergence_time:.2f} seconds")

# Visualization
rounds = list(range(1, num_rounds + 1))

plt.figure(figsize=(12, 6))

# Plot communication overhead
plt.subplot(1, 3, 1)
plt.plot(rounds, communication_overheads, marker='o')
plt.title('Communication Overhead per Round')
plt.xlabel('Round')
plt.ylabel('Communication Overhead (MB)')

# Plot accuracy
plt.subplot(1, 3, 2)
plt.plot(rounds, accuracies, marker='o')
plt.title('Global Model Accuracy per Round')
plt.xlabel('Round')
plt.ylabel('Accuracy')

# Plot round times
plt.subplot(1, 3, 3)
plt.plot(rounds, round_times, marker='o')
plt.title('Round Time')
plt.xlabel('Round')
plt.ylabel('Time (seconds)')

plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Round 1/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 1: 0.2095 MB
# Global model accuracy after round 1: 0.1448
# Round 2/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 2: 0.2095 MB
# Global model accuracy after round 2: 0.0427
# Round 3/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 3: 0.2095 MB
# Global model accuracy after round 3: 0.0347
# Round 4/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 4: 0.2095 MB
# Global model accuracy after round 4: 0.0422
# Round 5/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 5: 0.2095 MB
# Global model accuracy after round 5: 0.0112
# Round 6/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 6: 0.2095 MB
# Global model accuracy after round 6: 0.0096
# Round 7/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 7: 0.2095 MB
# Global model accuracy after round 7: 0.0096
# Round 8/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 8: 0.2095 MB
# Global model accuracy after round 8: 0.2062
# Round 9/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 9: 0.2095 MB
# Global model accuracy after round 9: 0.2067
# Round 10/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 10: 0.2095 MB
# Global model accuracy after round 10: 0.2067
# Round 11/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 11: 0.2095 MB
# Global model accuracy after round 11: 0.2067
# Round 12/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 12: 0.2095 MB
# Global model accuracy after round 12: 0.2067
# Round 13/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 13: 0.2095 MB
# Global model accuracy after round 13: 0.2062
# Round 14/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 14: 0.2095 MB
# Global model accuracy after round 14: 0.2062
# Round 15/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 15: 0.2095 MB
# Global model accuracy after round 15: 0.2057
# Round 16/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 16: 0.2095 MB
# Global model accuracy after round 16: 0.2057
# Round 17/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 17: 0.2095 MB
# Global model accuracy after round 17: 0.2057
# Round 18/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 18: 0.2095 MB
# Global model accuracy after round 18: 0.2062
# Round 19/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 19: 0.2095 MB
# Global model accuracy after round 19: 0.2067
# Round 20/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 20: 0.2095 MB
# Global model accuracy after round 20: 0.2062
# Round 21/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# ...
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 24: 0.2095 MB
# Global model accuracy after round 24: 0.2126
# Round 25/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 25: 0.2095 MB
# Global model accuracy after round 25: 0.2110
# Round 26/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 26: 0.2095 MB
# Global model accuracy after round 26: 0.2121
# Round 27/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 27: 0.2095 MB
# Global model accuracy after round 27: 0.2105
# Round 28/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 28: 0.2095 MB
# Global model accuracy after round 28: 0.2105
# Round 29/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 29: 0.2095 MB
# Global model accuracy after round 29: 0.2105
# Round 30/30
# Training on client 1
# Training on client 2
# Training on client 3
# Training on client 4
# Training on client 5
# Training on client 6
# Training on client 7
# Training on client 8
# Training on client 9
# Training on client 10
# Training on client 11
# Training on client 12
# Training on client 13
# Training on client 14
# Training on client 15
# Training on client 16
# Training on client 17
# Training on client 18
# Training on client 19
# Training on client 20
# Training on client 21
# Training on client 22
# Training on client 23
# Training on client 24
# Training on client 25
# Training on client 26
# Training on client 27
# Training on client 28
# Training on client 29
# Training on client 30
# Training on client 31
# Training on client 32
# Training on client 33
# Training on client 34
# Training on client 35
# Training on client 36
# Training on client 37
# Training on client 38
# Training on client 39
# Training on client 40
# Training on client 41
# Training on client 42
# Training on client 43
# Training on client 44
# Training on client 45
# Training on client 46
# Training on client 47
# Training on client 48
# Training on client 49
# Training on client 50
# Training on client 51
# Training on client 52
# Training on client 53
# Training on client 54
# Training on client 55
# Training on client 56
# Training on client 57
# Training on client 58
# Training on client 59
# Training on client 60
# Training on client 61
# Training on client 62
# Training on client 63
# Training on client 64
# Training on client 65
# Training on client 66
# Training on client 67
# Training on client 68
# Training on client 69
# Training on client 70
# Training on client 71
# Training on client 72
# Training on client 73
# Training on client 74
# Training on client 75
# Training on client 76
# Training on client 77
# Training on client 78
# Training on client 79
# Training on client 80
# Training on client 81
# Training on client 82
# Training on client 83
# Training on client 84
# Training on client 85
# Training on client 86
# Training on client 87
# Training on client 88
# Training on client 89
# Training on client 90
# Training on client 91
# Training on client 92
# Training on client 93
# Training on client 94
# Training on client 95
# Training on client 96
# Training on client 97
# Training on client 98
# Training on client 99
# Training on client 100
# Communication overhead for round 30: 0.2095 MB
# Global model accuracy after round 30: 0.2105
# Final global model accuracy: 0.2105
# Total communication overhead: 6.2857 MB
# Convergence not achieved within 30 rounds.

# %% [markdown]
# **CENTRALI**

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import time

# Load and preprocess the Air Quality dataset
def load_and_preprocess_data(filepath):
    # Load the dataset
    df = pd.read_excel(filepath)

    # Display the first few rows of the dataset
    print("First few rows of the dataset:")
    print(df.head())

    # Display the shape of the dataset
    print("\nShape of the dataset:")
    print(df.shape)

    # Display the column names
    print("\nColumn names:")
    print(df.columns)

    # Convert Time column to string
    df['Time'] = df['Time'].astype(str)

    # Combine Date and Time columns into a single datetime column
    df['Date_Time'] = pd.to_datetime(df['Date'].astype(str) + ' ' + df['Time'])
    df.drop(['Date', 'Time'], axis=1, inplace=True)

    # Replace comma with dot for decimal conversion and convert to numeric
    for col in df.columns:
        if df[col].dtype == 'object':
            df[col] = df[col].str.replace(',', '.').astype(float)

    # Interpolate missing values
    df = df.interpolate(method='linear')

    # Drop any remaining rows with missing values
    df = df.dropna()

    # Display the first few rows of the preprocessed data
    print("\nFirst few rows of the preprocessed data:")
    print(df.head())

    # Display the shape of the preprocessed data
    print("\nShape of the preprocessed data:")
    print(df.shape)

    # Check for null values in the preprocessed data
    print("\nNull values in the preprocessed data:")
    print(df.isnull().sum())

    # Convert to numpy array
    data = df.drop(['Date_Time'], axis=1).values

    # Normalize the data
    scaler = StandardScaler()
    data_scaled = scaler.fit_transform(data)

    # Display the shape of the scaled data
    print("\nShape of the scaled data:")
    print(data_scaled.shape)

    # Split the data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(data_scaled, data_scaled, test_size=0.2, random_state=42)

    return (X_train, y_train), (X_test, y_test), y_train.shape[1]

# File path to the dataset
file_path = '/content/drive/MyDrive/AirQualityUCI.xlsx'

# Load and preprocess data
(x_train, y_train), (x_test, y_test), num_classes = load_and_preprocess_data(file_path)

# Display the shapes of the training and testing sets
print("\nShape of the training data (X_train, y_train):")
print(x_train.shape, y_train.shape)
print("Shape of the testing data (X_test, y_test):")
print(x_test.shape, y_test.shape)

# Define the global RNN model
def create_rnn_model(input_shape, num_classes):
    model = tf.keras.Sequential([
        tf.keras.layers.LSTM(64, input_shape=input_shape, return_sequences=True),
        tf.keras.layers.LSTM(64),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(num_classes, activation='softmax')
    ])
    return model

# Create and compile the model
input_shape = (x_train.shape[1], 1)  # Adjust input shape for LSTM
model = create_rnn_model(input_shape, num_classes)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Reshape data for LSTM
x_train_reshaped = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
x_test_reshaped = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))

# Train the model
start_time = time.time()
history = model.fit(x_train_reshaped, y_train, epochs=30, batch_size=32, validation_data=(x_test_reshaped, y_test), verbose=1)
training_time = time.time() - start_time

# Evaluate the model
final_loss, final_accuracy = model.evaluate(x_test_reshaped, y_test, verbose=0)
print(f"Final model accuracy: {final_accuracy:.4f}")
print(f"Training time: {training_time:.2f} seconds")

# Visualization
plt.figure(figsize=(12, 6))

# Plot accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='test')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# First few rows of the dataset:
#         Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  \
# 0 2004-03-10  18:00:00     2.6      1360.00       150  11.881723
# 1 2004-03-10  19:00:00     2.0      1292.25       112   9.397165
# 2 2004-03-10  20:00:00     2.2      1402.00        88   8.997817
# 3 2004-03-10  21:00:00     2.2      1375.50        80   9.228796
# 4 2004-03-10  22:00:00     1.6      1272.25        51   6.518224
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0        1045.50    166.0       1056.25    113.0       1692.00      1267.50
# 1         954.75    103.0       1173.75     92.0       1558.75       972.25
# 2         939.25    131.0       1140.00    114.0       1554.50      1074.00
# 3         948.25    172.0       1092.00    122.0       1583.75      1203.25
# 4         835.50    131.0       1205.00    116.0       1490.00      1110.00
#
#        T         RH        AH
# 0  13.60  48.875001  0.757754
# 1  13.30  47.700000  0.725487
# 2  11.90  53.975000  0.750239
# 3  11.00  60.000000  0.786713
# 4  11.15  59.575001  0.788794
#
# Shape of the dataset:
# (9357, 15)
#
# Column names:
# Index(['Date', 'Time', 'CO(GT)', 'PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)',
#        'PT08.S2(NMHC)', 'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)',
#        'PT08.S5(O3)', 'T', 'RH', 'AH'],
#       dtype='object')
#
# First few rows of the preprocessed data:
#    CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  \
# 0     2.6      1360.00       150  11.881723        1045.50    166.0
# 1     2.0      1292.25       112   9.397165         954.75    103.0
# 2     2.2      1402.00        88   8.997817         939.25    131.0
# 3     2.2      1375.50        80   9.228796         948.25    172.0
# 4     1.6      1272.25        51   6.518224         835.50    131.0
#
#    PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)      T         RH  \
# 0       1056.25    113.0       1692.00      1267.50  13.60  48.875001
# 1       1173.75     92.0       1558.75       972.25  13.30  47.700000
# 2       1140.00    114.0       1554.50      1074.00  11.90  53.975000
# 3       1092.00    122.0       1583.75      1203.25  11.00  60.000000
# 4       1205.00    116.0       1490.00      1110.00  11.15  59.575001
#
#          AH           Date_Time
# 0  0.757754 2004-03-10 18:00:00
# 1  0.725487 2004-03-10 19:00:00
# 2  0.750239 2004-03-10 20:00:00
# 3  0.786713 2004-03-10 21:00:00
# 4  0.788794 2004-03-10 22:00:00
#
# Shape of the preprocessed data:
# (9357, 14)
#
# Null values in the preprocessed data:
# CO(GT)           0
# PT08.S1(CO)      0
# NMHC(GT)         0
# C6H6(GT)         0
# PT08.S2(NMHC)    0
# NOx(GT)          0
# PT08.S3(NOx)     0
# NO2(GT)          0
# PT08.S4(NO2)     0
# PT08.S5(O3)      0
# T                0
# RH               0
# AH               0
# Date_Time        0
# dtype: int64
#
# Shape of the scaled data:
# (9357, 13)
#
# Shape of the training data (X_train, y_train):
# (7485, 13) (7485, 13)
# Shape of the testing data (X_test, y_test):
# (1872, 13) (1872, 13)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.1928 - loss: -15.6207 - val_accuracy: 0.2580 - val_loss: -144.5250
# Epoch 2/30
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.2543 - loss: -245.8643 - val_accuracy: 0.2548 - val_loss: -633.7648
# Epoch 3/30
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.2528 - loss: -824.1372 - val_accuracy: 0.2505 - val_loss: -1443.5161
# Epoch 4/30
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.2454 - loss: -1865.6205 - val_accuracy: 0.2169 - val_loss: -2666.7356
# Epoch 5/30
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.2406 - loss: -3139.5056 - val_accuracy: 0.2393 - val_loss: -3954.4050
# Epoch 6/30
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.2356 - loss: -4623.5742 - val_accuracy: 0.2388 - val_loss: -5960.8066
# Epoch 7/30
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.2373 - loss: -6856.8081 - val_accuracy: 0.2137 - val_loss: -8159.8926
# Epoch 8/30
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.2400 - loss: -8886.7324 - val_accuracy: 0.2399 - val_loss: -10319.8613
# Epoch 9/30
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.2271 - loss: -10745.6592 - val_accuracy: 0.2500 - val_loss: -13009.9580
# Epoch 10/30
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.2208 - loss: -14221.4854 - val_accuracy: 0.1100 - val_loss: -15914.1250
# Epoch 11/30
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.2310 - loss: -17501.4570 - val_accuracy: 0.2415 - val_loss: -18806.2051
# Epoch 12/30
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.2361 - loss: -20259.5586 - val_accuracy: 0.0839 - val_loss: -22035.7715
# Epoch 13/30
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.2166 - loss: -23500.6855 - val_accuracy: 0.2644 - val_loss: -25206.3164
# Epoch 14/30
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.2156 - loss: -28039.8770 - val_accuracy: 0.2404 - val_loss: -29258.6094
# Epoch 15/30
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.2258 - loss: -31950.3789 - val_accuracy: 0.2425 - val_loss: -32731.5352
# Epoch 16/30
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.2119 - loss: -35823.8594 - val_accuracy: 0.2212 - val_loss: -37394.7422
# Epoch 17/30
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.2127 - loss: -39270.0312 - val_accuracy: 0.2217 - val_loss: -41842.0703
# Epoch 18/30
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.2223 - loss: -45906.5312 - val_accuracy: 0.2639 - val_loss: -46787.9961
# Epoch 19/30
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.2233 - loss: -49196.6211 - val_accuracy: 0.2495 - val_loss: -51301.5000
# Epoch 20/30
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.2057 - loss: -53932.5078 - val_accuracy: 0.0625 - val_loss: -56360.6328
# Epoch 21/30
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.2033 - loss: -60355.0938 - val_accuracy: 0.2404 - val_loss: -61568.9219
# Epoch 22/30
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.2196 - loss: -67501.4531 - val_accuracy: 0.2447 - val_loss: -66798.4453
# Epoch 23/30
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.2043 - loss: -70238.0391 - val_accuracy: 0.1330 - val_loss: -71833.5469
# Epoch 24/30
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.2071 - loss: -75283.7969 - val_accuracy: 0.2618 - val_loss: -78942.4453
# Epoch 25/30
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.2125 - loss: -83414.9609 - val_accuracy: 0.2420 - val_loss: -85217.5469
# Epoch 26/30
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.1937 - loss: -89975.0547 - val_accuracy: 0.2078 - val_loss: -91774.0547
# Epoch 27/30
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.2042 - loss: -98232.3203 - val_accuracy: 0.1074 - val_loss: -99219.2891
# Epoch 28/30
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.2027 - loss: -104412.5625 - val_accuracy: 0.2575 - val_loss: -104014.1406
# Epoch 29/30
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.2173 - loss: -111465.0078 - val_accuracy: 0.1127 - val_loss: -113402.9297
# Epoch 30/30
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.1977 - loss: -117984.0078 - val_accuracy: 0.1309 - val_loss: -118469.3125
# Final model accuracy: 0.1309
# Training time: 52.79 seconds
